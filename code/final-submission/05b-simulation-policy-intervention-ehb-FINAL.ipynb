# %%
#SIMULATION - POLICY INTERVENTION (Readme)
#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# Module conducts the following analysis:

# ---- Policy intervention simulation

# Module is input for:

# ---- Simulation-policy-effectiveness#
# ---- Simulation-treatment

# %%
#SET-UP
#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
setwd("/home/h1604190/Spatially-informed Demand-side Policies for Green H2 Diffusion/") 
check_and_load <- function(packages) {
  for (pkg in packages) {
    if (!requireNamespace(pkg, quietly = TRUE)) {
      message(paste("Installing missing package:", pkg))
      install.packages(pkg, dependencies = TRUE, repos = "https://cloud.r-project.org")
    }
    if (!(pkg %in% (.packages()))) {
      suppressPackageStartupMessages(library(pkg, character.only = TRUE))
    }
  }
}

# --- Required Libraries ---
required_packages <- c(
  "dplyr",      # data manipulation
  "Matrix",     # sparse matrices
  "FNN",        # nearest neighbors
  "sf",         # spatial data
  "tidyr",      # reshaping
  "tibble",     # tibbles
  "purrr",      # functional tools
  "data.table", # fast tables
  "patchwork"   # plot layout
)


check_and_load(required_packages)

# %%
#INPUTS AND SETTINGS
#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# --- Calibration Parameters ---
distance_cutoff_rotterdam <- 50000           # [m] Max distance for seeding initial adopters around Rotterdam
rotterdam_coords <- cbind(4.4786, 51.9244)   # Rotterdam coordinates (reference point for initialization)
start_year <- 1961                           # Start year of diffusion in calibration set
noise_multiplier <- 0.5                      # Noise multiplier for second-pass calibration (to avoid overfitting)
k_max_number <- 500                          # Max number of neighbors for KNN spatial weights
km_cutoff <- 120000                          # [m] Distance cutoff for adjacency matrix (optimized in calibration)

# --- Simulation Parameters ---
initial_share <- 0.01                        # Share of adopters at start of simulation (as fraction of eligible offtakers)
carbon_price_setting <- "carbon_price"       # Fossil scenario: "carbon_price", "flat_carbon_price", or "no_carbon_price"
n_simulations <- 250                        # Number of Monte Carlo simulation runs
start_year_sim <- 2024                       # Start year for prospective simulation
end_year <- 2100                             # End year for prospective simulation
intervention_volume <- 0.1                   # Fraction of plants targeted per sector-quantile group
quantile <- 4                                # Sectoral stratification granularity (quartiles)
seeds <- 1:n_simulations                     # reproducibility
saturation_setting <- "extended"           # switch to "restricted" / "extended" if needed
cost_setting <- "progressive"                       # switch to conservative / progressive if needed
simulation_years <- start_year_sim:end_year  # simulation years

# %%
# DATA FILES
#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
offtakers <- readRDS("/home/h1604190/First Submission/offtakers_centrality.rds")
cost_gap_data <- readRDS("/home/h1604190/Data/cost_gap_data.rds")
spatial_weights <- readRDS("/home/h1604190/First Submission/spatial_weights.rds")

# %%
# helper functions
#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# select intervention targets within a candidate group
filter_intervention_group <- function(df_group, type, k, seed) {
  if (type == "high") {
    slice_head(arrange(df_group, desc(contribution)), n = k)
  } else if (type == "low") {
    slice_head(arrange(df_group, contribution), n = k)
  } else {
    withr::with_seed(seed, slice_sample(df_group, n = k))
  }
}

# summarize annual uptake and policy cost for one run
summarize_run <- function(run_result) {
  run_result$adoption_plant %>%
    left_join(run_result$policy_cost, by = c("year", "plant_id")) %>%
    group_by(year) %>%
    summarise(
      annual_demand = sum(adoption * hydrogen_2050, na.rm = TRUE),
      annual_cost   = sum(policy_cost, na.rm = TRUE),
      .groups = "drop"
    )
}

# logistic adoption probability
adopt_prob <- function(beta0, beta1, spatial_influence_detrended,
                       beta2, cost_diff,
                       beta3, distance_to_waterway,
                       beta4, distance_to_pipeline,
                       beta5) {
  1 / (1 + exp(-(beta0 +
    beta1 * spatial_influence_detrended +
    beta2 * cost_diff +
    beta3 * distance_to_waterway +
    beta4 * distance_to_pipeline +
    beta5 * spatial_influence_detrended * cost_diff)))
}

# cumulative subsidy need over the simulation horizon
compute_cost_need <- function(years, sector_chr, cost_diff_lookup) {
  out <- numeric(length(sector_chr))

  for (yy in years) {
    cost_year <- cost_diff_lookup[[as.character(yy)]]

    if (is.null(cost_year) || !nrow(cost_year)) next

    cost_vec <- cost_year$cost_diff
    names(cost_vec) <- as.character(cost_year$sector)

    cd <- unname(cost_vec[sector_chr])
    cd[is.na(cd)] <- 0

    out <- out + pmin(cd, 0)
  }

  -out
}

# fast percent-rank helper
percent_rank_fast <- function(x) {
  x2 <- x
  ok <- !is.na(x2)
  out <- rep(NA_real_, length(x2))

  if (!any(ok)) return(out)

  r <- rank(x2[ok], ties.method = "average")
  n <- sum(ok)

  if (n == 1) {
    out[ok] <- 0
  } else {
    out[ok] <- (r - 1) / (n - 1)
  }

  out
}

# global score weights
#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

cost_weight_global <- 0.9
cent_weight_global <- 1 - cost_weight_global

# policy simulation inputs for score-based targeting
#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

offtakers_df <- offtakers %>%
  st_set_geometry(NULL) %>%
  mutate(beta6 = get(paste0("beta6_", saturation_setting))) %>%
  select(
    plant_id, sector, hydrogen_2050,
    beta0, beta1, beta2, beta3, beta4, beta5, beta6,
    distance_to_rotterdam, distance_to_waterway, distance_to_pipeline,
    betweenness, degree
  )

sector         <- offtakers_df$sector
plant_id       <- offtakers_df$plant_id
n_offtakers    <- nrow(offtakers_df)
unique_sectors <- unique(sector)

# model coefficients and covariates as vectors
beta0_vec <- offtakers_df$beta0
beta1_vec <- offtakers_df$beta1
beta2_vec <- offtakers_df$beta2
beta3_vec <- offtakers_df$beta3
beta4_vec <- offtakers_df$beta4
beta5_vec <- offtakers_df$beta5
beta6_vec <- offtakers_df$beta6

distance_rotterdam <- offtakers_df$distance_to_rotterdam
distance_waterway  <- offtakers_df$distance_to_waterway
distance_pipeline  <- offtakers_df$distance_to_pipeline
hydrogen_2050      <- offtakers_df$hydrogen_2050

# sector indexing for faster within-sector updates
sector_index  <- split(seq_len(n_offtakers), sector)
sector_factor <- as.integer(factor(sector, levels = unique_sectors))
n_sectors     <- length(unique_sectors)
sector_counts <- tabulate(sector_factor, nbins = n_sectors)

# yearly sector-level cost differences
cost_diff_lookup <- cost_gap_data %>%
  filter(
    green_scenario == cost_setting,
    fossil_scenario == carbon_price_setting
  ) %>%
  select(year, sector, cost_diff) %>%
  distinct(year, sector, .keep_all = TRUE) %>%
  mutate(sector = as.character(sector)) %>%
  split(.$year)

# candidate centrality scores for targeting
centrality_types <- list(
  betweenness = offtakers_df$betweenness,
  degree      = offtakers_df$degree
)

intervention_types <- c("baseline", "high", "low", "random")

# initial seed adoption near rotterdam
eligible_init <- which(
  distance_rotterdam <= distance_cutoff_rotterdam &
    beta6_vec > 0
)

set.seed(42)

selected_indices <- if (length(eligible_init) > 0) {
  sample(
    eligible_init,
    size = min(length(eligible_init), max(1, round(initial_share * length(eligible_init)))),
    replace = FALSE
  )
} else {
  integer(0)
}

initial_adoption <- rep.int(0, n_offtakers)
initial_adoption[selected_indices] <- 1

# simulation function
#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

run_simulation <- function(intervention_type = "baseline",
                           seed = 19,
                           contribution_score,
                           cost_weight = cost_weight_global,
                           cent_weight = cent_weight_global) {

  set.seed(seed)

  years   <- simulation_years
  n_years <- length(years)

  # storage matrices
  adoption_mat           <- matrix(0, n_offtakers, n_years)
  cost_diff_mat          <- matrix(0, n_offtakers, n_years)
  original_cost_diff_mat <- matrix(0, n_offtakers, n_years)
  policy_cost_mat        <- matrix(0, n_offtakers, n_years)

  influence_summary_list <- vector("list", n_years)
  influence_plant_list   <- vector("list", n_years)

  target_offtakers <- integer(0)

  # normalized targeting inputs
  cost_need <- compute_cost_need(years, as.character(sector), cost_diff_lookup)
  cost_q    <- 1 - percent_rank_fast(cost_need)
  cent_q    <- percent_rank_fast(contribution_score)

  score_df <- tibble(
    idx      = seq_len(n_offtakers),
    plant_id = plant_id,
    sector   = sector,
    cost_q   = cost_q,
    cent_q   = cent_q
  )

  # tiny jitter to break ties deterministically within seed
  jitter <- runif(n_offtakers, 0, 1e-9)

  # target selection for non-baseline interventions
  if (intervention_type != "baseline") {

    k <- max(1L, ceiling(intervention_volume * n_offtakers))

    cent_component <- switch(
      intervention_type,
      high   = cent_q,
      low    = 1 - cent_q,
      random = 0,
      0
    )

    if (intervention_type == "random") {
      cw <- 1
      sw <- 0
    } else {
      cw <- cost_weight
      sw <- cent_weight
    }

    composite_score <- cw * cost_q + sw * cent_component
    composite_score[is.na(composite_score)] <- -Inf

    ord <- order(composite_score + jitter, decreasing = TRUE)

    target_offtakers <- ord[seq_len(min(k, length(ord)))]
    target_offtakers <- target_offtakers[is.finite(composite_score[target_offtakers])]

    score_df <- score_df %>%
      mutate(
        composite_score   = composite_score,
        treated           = idx %in% target_offtakers,
        intervention_type = intervention_type
      )

  } else {

    score_df <- score_df %>%
      mutate(
        composite_score   = NA_real_,
        treated           = FALSE,
        intervention_type = intervention_type
      )
  }

  treated_flag_vec <- logical(n_offtakers)
  if (length(target_offtakers)) treated_flag_vec[target_offtakers] <- TRUE

  previous_adoption <- initial_adoption

  # continuous vs binary adoption sectors
  continuous_sectors <- c("Heavy duty", "Aviation", "Shipping")
  continuous_flag    <- sector %in% continuous_sectors
  discrete_sectors   <- unique_sectors[!unique_sectors %in% continuous_sectors]

  for (tt in seq_len(n_years)) {

    year <- years[tt]

    # spatial influence from currently adopted neighbors
    spatial_influence <- as.numeric(spatial_weights %*% previous_adoption)
    spatial_influence[is.na(spatial_influence)] <- 0
    spatial_influence_detrended <- spatial_influence - mean(spatial_influence)

    # store influence diagnostics for treated vs untreated groups
    if (length(target_offtakers)) {
      influence_summary_list[[tt]] <- tibble(
        year                         = year,
        treated_influence_received   = sum(spatial_influence[treated_flag_vec]),
        untreated_influence_received = sum(spatial_influence[!treated_flag_vec]),
        mean_adoption_treated        = mean(previous_adoption[treated_flag_vec]),
        mean_adoption_untreated      = mean(previous_adoption[!treated_flag_vec])
      )

      influence_plant_list[[tt]] <- tibble(
        year              = year,
        plant_id          = plant_id,
        spatial_influence = spatial_influence,
        treated           = treated_flag_vec
      )
    }

    # current-year sector-level cost differences
    cost_year <- cost_diff_lookup[[as.character(year)]]

    if (is.null(cost_year)) {
      cost_diff <- rep(0, n_offtakers)
    } else {
      cost_vec <- cost_year$cost_diff
      names(cost_vec) <- cost_year$sector
      cost_diff <- unname(cost_vec[sector])
      cost_diff[is.na(cost_diff)] <- 0
    }

    original_cost_diff <- cost_diff

    # intervention removes negative cost gaps for treated agents
    if (length(target_offtakers)) {
      cost_diff[target_offtakers] <- pmax(0, cost_diff[target_offtakers])
    }

    cost_diff_mat[, tt]          <- cost_diff
    original_cost_diff_mat[, tt] <- original_cost_diff

    # raw adoption probability
    p_raw <- adopt_prob(
      beta0_vec,
      beta1_vec, spatial_influence_detrended,
      beta2_vec, cost_diff,
      beta3_vec, distance_waterway,
      beta4_vec, distance_pipeline,
      beta5_vec
    )
    p_raw[is.na(p_raw)] <- 0

    # residual adoption headroom within sectors
    sector_sum      <- rowsum(previous_adoption, group = sector_factor, reorder = FALSE)
    sector_mean     <- as.numeric(sector_sum) / sector_counts
    sector_mean_vec <- sector_mean[sector_factor]

    residual_share <- pmax(
      0,
      (beta6_vec - sector_mean_vec) / pmax(1 - sector_mean_vec, 1e-6)
    )

    residual_p <- p_raw * residual_share
    residual_p[is.na(residual_p)] <- 0

    adoption <- previous_adoption

    # continuous adoption update
    if (any(continuous_flag)) {
      idx_c <- which(continuous_flag)
      adoption[idx_c] <- 1 - (1 - adoption[idx_c]) * (1 - residual_p[idx_c])
    }

    # binary adoption update
    for (s in discrete_sectors) {
      idx_s <- sector_index[[s]]
      adoption[idx_s] <- pmax(
        adoption[idx_s],
        rbinom(length(idx_s), 1, residual_p[idx_s])
      )
    }

    adoption[beta6_vec == 0] <- 0

    adoption_mat[, tt] <- adoption

    # policy cost from closing negative cost gaps
    policy_cost_mat[, tt] <- ifelse(
      original_cost_diff < 0 & cost_diff == 0,
      hydrogen_2050 * (-original_cost_diff) * adoption * 33000 / 1e9,
      0
    )

    previous_adoption <- adoption
  }

  # reshape outputs to long format
  year_rep   <- rep(years, each = n_offtakers)
  plant_rep  <- rep(plant_id, times = n_years)
  sector_rep <- rep(sector, times = n_years)
  h2050_rep  <- rep(hydrogen_2050, times = n_years)

  adoption_plant_df <- tibble(
    year               = year_rep,
    plant_id           = plant_rep,
    sector             = sector_rep,
    adoption           = as.vector(adoption_mat),
    cost_diff          = as.vector(cost_diff_mat),
    original_cost_diff = as.vector(original_cost_diff_mat),
    hydrogen_2050      = h2050_rep
  )

  policy_cost_df <- tibble(
    year        = year_rep,
    plant_id    = plant_rep,
    policy_cost = as.vector(policy_cost_mat)
  )

  cost_diff_df <- tibble(
    year      = year_rep,
    plant_id  = plant_rep,
    cost_diff = as.vector(cost_diff_mat)
  )

  list(
    adoption_plant    = adoption_plant_df,
    policy_cost       = policy_cost_df,
    cost_diff         = cost_diff_df,
    influence_plant   = if (length(target_offtakers)) bind_rows(influence_plant_list) else NULL,
    influence_summary = if (length(target_offtakers)) bind_rows(influence_summary_list) else NULL,
    treated_offtakers = if (length(target_offtakers)) score_df else NULL
  )
}

# runs and aggregation
#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

results_all <- list()
results_all_dist <- list()

for (i in seq_len(n_simulations)) {
  seed_i <- seeds[i]

  for (cent_name in names(centrality_types)) {

    score <- centrality_types[[cent_name]]

    for (intervention in intervention_types) {

      key <- paste(cent_name, intervention, sep = "_")

      run_result <- run_simulation(
        intervention_type  = intervention,
        seed               = seed_i,
        contribution_score = score
      )

      this_summary <- summarize_run(run_result)

      # first run initializes storage
      if (i == 1) {

        results_all[[key]]      <- run_result
        results_all_dist[[key]] <- list(this_summary)

      } else {

        # keep all annual summaries by run
        results_all_dist[[key]][[i]] <- this_summary

        # running average for adoption outputs
        base <- results_all[[key]]$adoption_plant
        new  <- run_result$adoption_plant

        num_cols <- setdiff(names(base), c("year", "plant_id", "sector", "hydrogen_2050"))
        base[num_cols] <- (base[num_cols] * (i - 1) + new[num_cols]) / i
        results_all[[key]]$adoption_plant <- base

        # running average for policy cost
        base <- results_all[[key]]$policy_cost
        new  <- run_result$policy_cost

        base$policy_cost <- (base$policy_cost * (i - 1) + new$policy_cost) / i
        results_all[[key]]$policy_cost <- base

        # running average for cost differences
        base <- results_all[[key]]$cost_diff
        new  <- run_result$cost_diff

        base$cost_diff <- (base$cost_diff * (i - 1) + new$cost_diff) / i
        results_all[[key]]$cost_diff <- base

        # running average for plant-level influence diagnostics
        base_infl <- results_all[[key]]$influence_plant
        new_infl  <- run_result$influence_plant

        if (!is.null(base_infl) && !is.null(new_infl) &&
            nrow(base_infl) > 0 && nrow(new_infl) > 0) {
          base_infl$spatial_influence <- (base_infl$spatial_influence * (i - 1) + new_infl$spatial_influence) / i
          results_all[[key]]$influence_plant <- base_infl
        }

        # running average for aggregate influence diagnostics
        base_sum <- results_all[[key]]$influence_summary
        new_sum  <- run_result$influence_summary

        if (!is.null(base_sum) && !is.null(new_sum) &&
            nrow(base_sum) > 0 && nrow(new_sum) > 0) {
          num_cols <- setdiff(names(base_sum), "year")
          base_sum[num_cols] <- (base_sum[num_cols] * (i - 1) + new_sum[num_cols]) / i
          results_all[[key]]$influence_summary <- base_sum
        }
      }

      message(sprintf("[%s] finished run %d/%d for %s",
                      Sys.time(), i, n_simulations, key))

      rm(run_result)
      if (i %% 5 == 0) gc()
    }
  }
}

# save per-run summaries
saveRDS(results_all_dist, "results_all_dist_extended_progressive_auction.rds")
# Out:
# [2026-03-25 10:06:22.342437] finished run 1/250 for betweenness_baseline
#
# [2026-03-25 10:06:23.484353] finished run 1/250 for betweenness_high
#
# [2026-03-25 10:06:24.459014] finished run 1/250 for betweenness_low
#
# [2026-03-25 10:06:25.322365] finished run 1/250 for betweenness_random
#
# [2026-03-25 10:06:25.980799] finished run 1/250 for degree_baseline
#
# [2026-03-25 10:06:26.814075] finished run 1/250 for degree_high
#
# [2026-03-25 10:06:27.669989] finished run 1/250 for degree_low
#
# [2026-03-25 10:06:28.36516] finished run 1/250 for degree_random
#
# [2026-03-25 10:06:29.198842] finished run 2/250 for betweenness_baseline
#
# [2026-03-25 10:06:29.936717] finished run 2/250 for betweenness_high
#
# [2026-03-25 10:06:30.737623] finished run 2/250 for betweenness_low
#
# [2026-03-25 10:06:31.374204] finished run 2/250 for betweenness_random
#
# [2026-03-25 10:06:32.033391] finished run 2/250 for degree_baseline
#
# [2026-03-25 10:06:32.822213] finished run 2/250 for degree_high
#
# [2026-03-25 10:06:33.554253] finished run 2/250 for degree_low
#
# [2026-03-25 10:06:34.221465] finished run 2/250 for degree_random
#
# [2026-03-25 10:06:34.872236] finished run 3/250 for betweenness_baseline
#
# [2026-03-25 10:06:35.496709] finished run 3/250 for betweenness_high
#
# [2026-03-25 10:06:36.143077] finished run 3/250 for betweenness_low
#
# [2026-03-25 10:06:36.770656] finished run 3/250 for betweenness_random
#
# [2026-03-25 10:06:37.281614] finished run 3/250 for degree_baseline
#
# [2026-03-25 10:06:37.913635] finished run 3/250 for degree_high
#
# [2026-03-25 10:06:38.69643] finished run 3/250 for degree_low
#
# [2026-03-25 10:06:39.318205] finished run 3/250 for degree_random
#
# [2026-03-25 10:06:39.818985] finished run 4/250 for betweenness_baseline
#
# [2026-03-25 10:06:40.443247] finished run 4/250 for betweenness_high
#
# [2026-03-25 10:06:41.252121] finished run 4/250 for betweenness_low
#
# [2026-03-25 10:06:41.886525] finished run 4/250 for betweenness_random
#
# [2026-03-25 10:06:42.387091] finished run 4/250 for degree_baseline
#
# [2026-03-25 10:06:43.012311] finished run 4/250 for degree_high
#
# [2026-03-25 10:06:43.637095] finished run 4/250 for degree_low
#
# [2026-03-25 10:06:44.434277] finished run 4/250 for degree_random
#
# [2026-03-25 10:06:44.928413] finished run 5/250 for betweenness_baseline
#
# [2026-03-25 10:06:45.730532] finished run 5/250 for betweenness_high
#
# [2026-03-25 10:06:46.54976] finished run 5/250 for betweenness_low
#
# [2026-03-25 10:06:47.320163] finished run 5/250 for betweenness_random
#
# [2026-03-25 10:06:47.972589] finished run 5/250 for degree_baseline
#
# [2026-03-25 10:06:48.744097] finished run 5/250 for degree_high
#
# [2026-03-25 10:06:49.558766] finished run 5/250 for degree_low
#
# [2026-03-25 10:06:50.363818] finished run 5/250 for degree_random
#
# [2026-03-25 10:06:51.026809] finished run 6/250 for betweenness_baseline
#
# [2026-03-25 10:06:51.656348] finished run 6/250 for betweenness_high
#
# [2026-03-25 10:06:52.282392] finished run 6/250 for betweenness_low
#
# [2026-03-25 10:06:53.056285] finished run 6/250 for betweenness_random
#
# [2026-03-25 10:06:53.707906] finished run 6/250 for degree_baseline
#
# [2026-03-25 10:06:54.327283] finished run 6/250 for degree_high
#
# [2026-03-25 10:06:55.120344] finished run 6/250 for degree_low
#
# [2026-03-25 10:06:55.764316] finished run 6/250 for degree_random
#
# [2026-03-25 10:06:56.290776] finished run 7/250 for betweenness_baseline
#
# [2026-03-25 10:06:57.115313] finished run 7/250 for betweenness_high
#
# [2026-03-25 10:06:57.759545] finished run 7/250 for betweenness_low
#
# [2026-03-25 10:06:58.391842] finished run 7/250 for betweenness_random
#
# [2026-03-25 10:06:59.053202] finished run 7/250 for degree_baseline
#
# [2026-03-25 10:06:59.71005] finished run 7/250 for degree_high
#
# [2026-03-25 10:07:00.357429] finished run 7/250 for degree_low
#
# [2026-03-25 10:07:01.13813] finished run 7/250 for degree_random
#
# [2026-03-25 10:07:01.637525] finished run 8/250 for betweenness_baseline
#
# [2026-03-25 10:07:02.264819] finished run 8/250 for betweenness_high
#
# [2026-03-25 10:07:03.058161] finished run 8/250 for betweenness_low
#
# [2026-03-25 10:07:03.679415] finished run 8/250 for betweenness_random
#
# [2026-03-25 10:07:04.182215] finished run 8/250 for degree_baseline
#
# [2026-03-25 10:07:04.965472] finished run 8/250 for degree_high
#
# [2026-03-25 10:07:05.592231] finished run 8/250 for degree_low
#
# [2026-03-25 10:07:06.218703] finished run 8/250 for degree_random
#
# [2026-03-25 10:07:06.889551] finished run 9/250 for betweenness_baseline
#
# [2026-03-25 10:07:07.515009] finished run 9/250 for betweenness_high
#
# [2026-03-25 10:07:08.152354] finished run 9/250 for betweenness_low
#
# [2026-03-25 10:07:08.799959] finished run 9/250 for betweenness_random
#
# [2026-03-25 10:07:09.46106] finished run 9/250 for degree_baseline
#
# [2026-03-25 10:07:10.088054] finished run 9/250 for degree_high
#
# [2026-03-25 10:07:10.719218] finished run 9/250 for degree_low
#
# [2026-03-25 10:07:11.501927] finished run 9/250 for degree_random
#
# [2026-03-25 10:07:12.002686] finished run 10/250 for betweenness_baseline
#
# [2026-03-25 10:07:12.781659] finished run 10/250 for betweenness_high
#
# [2026-03-25 10:07:13.557183] finished run 10/250 for betweenness_low
#
# [2026-03-25 10:07:14.340123] finished run 10/250 for betweenness_random
#
# [2026-03-25 10:07:14.996271] finished run 10/250 for degree_baseline
#
# [2026-03-25 10:07:15.780097] finished run 10/250 for degree_high
#
# [2026-03-25 10:07:16.557939] finished run 10/250 for degree_low
#
# [2026-03-25 10:07:17.340363] finished run 10/250 for degree_random
#
# [2026-03-25 10:07:17.999746] finished run 11/250 for betweenness_baseline
#
# [2026-03-25 10:07:18.655663] finished run 11/250 for betweenness_high
#
# [2026-03-25 10:07:19.439199] finished run 11/250 for betweenness_low
#
# [2026-03-25 10:07:20.063852] finished run 11/250 for betweenness_random
#
# [2026-03-25 10:07:20.585676] finished run 11/250 for degree_baseline
#
# [2026-03-25 10:07:21.375097] finished run 11/250 for degree_high
#
# [2026-03-25 10:07:21.998298] finished run 11/250 for degree_low
#
# [2026-03-25 10:07:22.623061] finished run 11/250 for degree_random
#
# [2026-03-25 10:07:23.28377] finished run 12/250 for betweenness_baseline
#
# [2026-03-25 10:07:23.906759] finished run 12/250 for betweenness_high
#
# [2026-03-25 10:07:24.530816] finished run 12/250 for betweenness_low
#
# [2026-03-25 10:07:25.318457] finished run 12/250 for betweenness_random
#
# [2026-03-25 10:07:25.820449] finished run 12/250 for degree_baseline
#
# [2026-03-25 10:07:26.447448] finished run 12/250 for degree_high
#
# [2026-03-25 10:07:27.232157] finished run 12/250 for degree_low
#
# [2026-03-25 10:07:27.862376] finished run 12/250 for degree_random
#
# [2026-03-25 10:07:28.382457] finished run 13/250 for betweenness_baseline
#
# [2026-03-25 10:07:29.167262] finished run 13/250 for betweenness_high
#
# [2026-03-25 10:07:29.819065] finished run 13/250 for betweenness_low
#
# [2026-03-25 10:07:30.452272] finished run 13/250 for betweenness_random
#
# [2026-03-25 10:07:30.953274] finished run 13/250 for degree_baseline
#
# [2026-03-25 10:07:31.734618] finished run 13/250 for degree_high
#
# [2026-03-25 10:07:32.358485] finished run 13/250 for degree_low
#
# [2026-03-25 10:07:33.135513] finished run 13/250 for degree_random
#
# [2026-03-25 10:07:33.79076] finished run 14/250 for betweenness_baseline
#
# [2026-03-25 10:07:34.413765] finished run 14/250 for betweenness_high
#
# [2026-03-25 10:07:35.039232] finished run 14/250 for betweenness_low
#
# [2026-03-25 10:07:35.669399] finished run 14/250 for betweenness_random
#
# [2026-03-25 10:07:36.333777] finished run 14/250 for degree_baseline
#
# [2026-03-25 10:07:36.961474] finished run 14/250 for degree_high
#
# [2026-03-25 10:07:37.595576] finished run 14/250 for degree_low
#
# [2026-03-25 10:07:38.378558] finished run 14/250 for degree_random
#
# [2026-03-25 10:07:38.882472] finished run 15/250 for betweenness_baseline
#
# [2026-03-25 10:07:39.665086] finished run 15/250 for betweenness_high
#
# [2026-03-25 10:07:40.457305] finished run 15/250 for betweenness_low
#
# [2026-03-25 10:07:41.23834] finished run 15/250 for betweenness_random
#
# [2026-03-25 10:07:41.895097] finished run 15/250 for degree_baseline
#
# [2026-03-25 10:07:42.676108] finished run 15/250 for degree_high
#
# [2026-03-25 10:07:43.445694] finished run 15/250 for degree_low
#
# [2026-03-25 10:07:44.224236] finished run 15/250 for degree_random
#
# [2026-03-25 10:07:44.881457] finished run 16/250 for betweenness_baseline
#
# [2026-03-25 10:07:45.529744] finished run 16/250 for betweenness_high
#
# [2026-03-25 10:07:46.317604] finished run 16/250 for betweenness_low
#
# [2026-03-25 10:07:46.94683] finished run 16/250 for betweenness_random
#
# [2026-03-25 10:07:47.455722] finished run 16/250 for degree_baseline
#
# [2026-03-25 10:07:48.238824] finished run 16/250 for degree_high
#
# [2026-03-25 10:07:48.86311] finished run 16/250 for degree_low
#
# [2026-03-25 10:07:49.49218] finished run 16/250 for degree_random
#
# [2026-03-25 10:07:50.155332] finished run 17/250 for betweenness_baseline
#
# [2026-03-25 10:07:50.781255] finished run 17/250 for betweenness_high
#
# [2026-03-25 10:07:51.56457] finished run 17/250 for betweenness_low
#
# [2026-03-25 10:07:52.197957] finished run 17/250 for betweenness_random
#
# [2026-03-25 10:07:52.871796] finished run 17/250 for degree_baseline
#
# [2026-03-25 10:07:53.485687] finished run 17/250 for degree_high
#
# [2026-03-25 10:07:54.14083] finished run 17/250 for degree_low
#
# [2026-03-25 10:07:54.774397] finished run 17/250 for degree_random
#
# [2026-03-25 10:07:55.282959] finished run 18/250 for betweenness_baseline
#
# [2026-03-25 10:07:56.067214] finished run 18/250 for betweenness_high
#
# [2026-03-25 10:07:56.692846] finished run 18/250 for betweenness_low
#
# [2026-03-25 10:07:57.323586] finished run 18/250 for betweenness_random
#
# [2026-03-25 10:07:57.989531] finished run 18/250 for degree_baseline
#
# [2026-03-25 10:07:58.611974] finished run 18/250 for degree_high
#
# [2026-03-25 10:07:59.397105] finished run 18/250 for degree_low
#
# [2026-03-25 10:08:00.0206] finished run 18/250 for degree_random
#
# [2026-03-25 10:08:00.525542] finished run 19/250 for betweenness_baseline
#
# [2026-03-25 10:08:01.146061] finished run 19/250 for betweenness_high
#
# [2026-03-25 10:08:01.773612] finished run 19/250 for betweenness_low
#
# [2026-03-25 10:08:02.554071] finished run 19/250 for betweenness_random
#
# [2026-03-25 10:08:03.053188] finished run 19/250 for degree_baseline
#
# [2026-03-25 10:08:03.677914] finished run 19/250 for degree_high
#
# [2026-03-25 10:08:04.460007] finished run 19/250 for degree_low
#
# [2026-03-25 10:08:05.084163] finished run 19/250 for degree_random
#
# [2026-03-25 10:08:05.589959] finished run 20/250 for betweenness_baseline
#
# [2026-03-25 10:08:06.369635] finished run 20/250 for betweenness_high
#
# [2026-03-25 10:08:07.145968] finished run 20/250 for betweenness_low
#
# [2026-03-25 10:08:07.925812] finished run 20/250 for betweenness_random
#
# [2026-03-25 10:08:08.581651] finished run 20/250 for degree_baseline
#
# [2026-03-25 10:08:09.365485] finished run 20/250 for degree_high
#
# [2026-03-25 10:08:10.142169] finished run 20/250 for degree_low
#
# [2026-03-25 10:08:10.923047] finished run 20/250 for degree_random
#
# [2026-03-25 10:08:11.57795] finished run 21/250 for betweenness_baseline
#
# [2026-03-25 10:08:12.201173] finished run 21/250 for betweenness_high
#
# [2026-03-25 10:08:12.82976] finished run 21/250 for betweenness_low
#
# [2026-03-25 10:08:13.4548] finished run 21/250 for betweenness_random
#
# [2026-03-25 10:08:14.115108] finished run 21/250 for degree_baseline
#
# [2026-03-25 10:08:14.747726] finished run 21/250 for degree_high
#
# [2026-03-25 10:08:15.376951] finished run 21/250 for degree_low
#
# [2026-03-25 10:08:16.157013] finished run 21/250 for degree_random
#
# [2026-03-25 10:08:16.660403] finished run 22/250 for betweenness_baseline
#
# [2026-03-25 10:08:17.296025] finished run 22/250 for betweenness_high
#
# [2026-03-25 10:08:17.946671] finished run 22/250 for betweenness_low
#
# [2026-03-25 10:08:18.590695] finished run 22/250 for betweenness_random
#
# [2026-03-25 10:08:19.259204] finished run 22/250 for degree_baseline
#
# [2026-03-25 10:08:19.887291] finished run 22/250 for degree_high
#
# [2026-03-25 10:08:20.518626] finished run 22/250 for degree_low
#
# [2026-03-25 10:08:21.302978] finished run 22/250 for degree_random
#
# [2026-03-25 10:08:21.798856] finished run 23/250 for betweenness_baseline
#
# [2026-03-25 10:08:22.426573] finished run 23/250 for betweenness_high
#
# [2026-03-25 10:08:23.050071] finished run 23/250 for betweenness_low
#
# [2026-03-25 10:08:23.846024] finished run 23/250 for betweenness_random
#
# [2026-03-25 10:08:24.341023] finished run 23/250 for degree_baseline
#
# [2026-03-25 10:08:24.971946] finished run 23/250 for degree_high
#
# [2026-03-25 10:08:25.601717] finished run 23/250 for degree_low
#
# [2026-03-25 10:08:26.383473] finished run 23/250 for degree_random
#
# [2026-03-25 10:08:26.881046] finished run 24/250 for betweenness_baseline
#
# [2026-03-25 10:08:27.539399] finished run 24/250 for betweenness_high
#
# [2026-03-25 10:08:28.17583] finished run 24/250 for betweenness_low
#
# [2026-03-25 10:08:28.820401] finished run 24/250 for betweenness_random
#
# [2026-03-25 10:08:29.33294] finished run 24/250 for degree_baseline
#
# [2026-03-25 10:08:30.106289] finished run 24/250 for degree_high
#
# [2026-03-25 10:08:30.732291] finished run 24/250 for degree_low
#
# [2026-03-25 10:08:31.388616] finished run 24/250 for degree_random
#
# [2026-03-25 10:08:31.88489] finished run 25/250 for betweenness_baseline
#
# [2026-03-25 10:08:32.666799] finished run 25/250 for betweenness_high
#
# [2026-03-25 10:08:33.443151] finished run 25/250 for betweenness_low
#
# [2026-03-25 10:08:34.22283] finished run 25/250 for betweenness_random
#
# [2026-03-25 10:08:34.878859] finished run 25/250 for degree_baseline
#
# [2026-03-25 10:08:35.659624] finished run 25/250 for degree_high
#
# [2026-03-25 10:08:36.439064] finished run 25/250 for degree_low
#
# [2026-03-25 10:08:37.221138] finished run 25/250 for degree_random
#
# [2026-03-25 10:08:37.89045] finished run 26/250 for betweenness_baseline
#
# [2026-03-25 10:08:38.532701] finished run 26/250 for betweenness_high
#
# [2026-03-25 10:08:39.321191] finished run 26/250 for betweenness_low
#
# [2026-03-25 10:08:39.944667] finished run 26/250 for betweenness_random
#
# [2026-03-25 10:08:40.605959] finished run 26/250 for degree_baseline
#
# [2026-03-25 10:08:41.230854] finished run 26/250 for degree_high
#
# [2026-03-25 10:08:41.85896] finished run 26/250 for degree_low
#
# [2026-03-25 10:08:42.642531] finished run 26/250 for degree_random
#
# [2026-03-25 10:08:43.143421] finished run 27/250 for betweenness_baseline
#
# [2026-03-25 10:08:43.915511] finished run 27/250 for betweenness_high
#
# [2026-03-25 10:08:44.538489] finished run 27/250 for betweenness_low
#
# [2026-03-25 10:08:45.203101] finished run 27/250 for betweenness_random
#
# [2026-03-25 10:08:45.700374] finished run 27/250 for degree_baseline
#
# [2026-03-25 10:08:46.334585] finished run 27/250 for degree_high
#
# [2026-03-25 10:08:47.115525] finished run 27/250 for degree_low
#
# [2026-03-25 10:08:47.743521] finished run 27/250 for degree_random
#
# [2026-03-25 10:08:48.402611] finished run 28/250 for betweenness_baseline
#
# [2026-03-25 10:08:49.184577] finished run 28/250 for betweenness_high
#
# [2026-03-25 10:08:49.805324] finished run 28/250 for betweenness_low
#
# [2026-03-25 10:08:50.435301] finished run 28/250 for betweenness_random
#
# [2026-03-25 10:08:50.94172] finished run 28/250 for degree_baseline
#
# [2026-03-25 10:08:51.570724] finished run 28/250 for degree_high
#
# [2026-03-25 10:08:52.358893] finished run 28/250 for degree_low
#
# [2026-03-25 10:08:52.995412] finished run 28/250 for degree_random
#
# [2026-03-25 10:08:53.503924] finished run 29/250 for betweenness_baseline
#
# [2026-03-25 10:08:54.132639] finished run 29/250 for betweenness_high
#
# [2026-03-25 10:08:54.913808] finished run 29/250 for betweenness_low
#
# [2026-03-25 10:08:55.543134] finished run 29/250 for betweenness_random
#
# [2026-03-25 10:08:56.201644] finished run 29/250 for degree_baseline
#
# [2026-03-25 10:08:56.827646] finished run 29/250 for degree_high
#
# [2026-03-25 10:08:57.462296] finished run 29/250 for degree_low
#
# [2026-03-25 10:08:58.094925] finished run 29/250 for degree_random
#
# [2026-03-25 10:08:58.752321] finished run 30/250 for betweenness_baseline
#
# [2026-03-25 10:08:59.530734] finished run 30/250 for betweenness_high
#
# [2026-03-25 10:09:00.30917] finished run 30/250 for betweenness_low
#
# [2026-03-25 10:09:01.087858] finished run 30/250 for betweenness_random
#
# [2026-03-25 10:09:01.750982] finished run 30/250 for degree_baseline
#
# [2026-03-25 10:09:02.530619] finished run 30/250 for degree_high
#
# [2026-03-25 10:09:03.311435] finished run 30/250 for degree_low
#
# [2026-03-25 10:09:04.094404] finished run 30/250 for degree_random
#
# [2026-03-25 10:09:04.748878] finished run 31/250 for betweenness_baseline
#
# [2026-03-25 10:09:05.388017] finished run 31/250 for betweenness_high
#
# [2026-03-25 10:09:06.018384] finished run 31/250 for betweenness_low
#
# [2026-03-25 10:09:06.651065] finished run 31/250 for betweenness_random
#
# [2026-03-25 10:09:07.32213] finished run 31/250 for degree_baseline
#
# [2026-03-25 10:09:07.948254] finished run 31/250 for degree_high
#
# [2026-03-25 10:09:08.732937] finished run 31/250 for degree_low
#
# [2026-03-25 10:09:09.361024] finished run 31/250 for degree_random
#
# [2026-03-25 10:09:09.863165] finished run 32/250 for betweenness_baseline
#
# [2026-03-25 10:09:10.645304] finished run 32/250 for betweenness_high
#
# [2026-03-25 10:09:11.268979] finished run 32/250 for betweenness_low
#
# [2026-03-25 10:09:11.907841] finished run 32/250 for betweenness_random
#
# [2026-03-25 10:09:12.412455] finished run 32/250 for degree_baseline
#
# [2026-03-25 10:09:13.075431] finished run 32/250 for degree_high
#
# [2026-03-25 10:09:13.860366] finished run 32/250 for degree_low
#
# [2026-03-25 10:09:14.479954] finished run 32/250 for degree_random
#
# [2026-03-25 10:09:14.984048] finished run 33/250 for betweenness_baseline
#
# [2026-03-25 10:09:15.767902] finished run 33/250 for betweenness_high
#
# [2026-03-25 10:09:16.394463] finished run 33/250 for betweenness_low
#
# [2026-03-25 10:09:17.184356] finished run 33/250 for betweenness_random
#
# [2026-03-25 10:09:17.689711] finished run 33/250 for degree_baseline
#
# [2026-03-25 10:09:18.320178] finished run 33/250 for degree_high
#
# [2026-03-25 10:09:19.110007] finished run 33/250 for degree_low
#
# [2026-03-25 10:09:19.732777] finished run 33/250 for degree_random
#
# [2026-03-25 10:09:20.244471] finished run 34/250 for betweenness_baseline
#
# [2026-03-25 10:09:21.031144] finished run 34/250 for betweenness_high
#
# [2026-03-25 10:09:21.665141] finished run 34/250 for betweenness_low
#
# [2026-03-25 10:09:22.293892] finished run 34/250 for betweenness_random
#
# [2026-03-25 10:09:22.801662] finished run 34/250 for degree_baseline
#
# [2026-03-25 10:09:23.594958] finished run 34/250 for degree_high
#
# [2026-03-25 10:09:24.21713] finished run 34/250 for degree_low
#
# [2026-03-25 10:09:24.842416] finished run 34/250 for degree_random
#
# [2026-03-25 10:09:25.35024] finished run 35/250 for betweenness_baseline
#
# [2026-03-25 10:09:26.128732] finished run 35/250 for betweenness_high
#
# [2026-03-25 10:09:26.901306] finished run 35/250 for betweenness_low
#
# [2026-03-25 10:09:27.672289] finished run 35/250 for betweenness_random
#
# [2026-03-25 10:09:28.321718] finished run 35/250 for degree_baseline
#
# [2026-03-25 10:09:29.103406] finished run 35/250 for degree_high
#
# [2026-03-25 10:09:29.879236] finished run 35/250 for degree_low
#
# [2026-03-25 10:09:30.655508] finished run 35/250 for degree_random
#
# [2026-03-25 10:09:31.304971] finished run 36/250 for betweenness_baseline
#
# [2026-03-25 10:09:31.92927] finished run 36/250 for betweenness_high
#
# [2026-03-25 10:09:32.555768] finished run 36/250 for betweenness_low
#
# [2026-03-25 10:09:33.181067] finished run 36/250 for betweenness_random
#
# [2026-03-25 10:09:33.844458] finished run 36/250 for degree_baseline
#
# [2026-03-25 10:09:34.463951] finished run 36/250 for degree_high
#
# [2026-03-25 10:09:35.246367] finished run 36/250 for degree_low
#
# [2026-03-25 10:09:35.870428] finished run 36/250 for degree_random
#
# [2026-03-25 10:09:36.375271] finished run 37/250 for betweenness_baseline
#
# [2026-03-25 10:09:37.157062] finished run 37/250 for betweenness_high
#
# [2026-03-25 10:09:37.779997] finished run 37/250 for betweenness_low
#
# [2026-03-25 10:09:38.415499] finished run 37/250 for betweenness_random
#
# [2026-03-25 10:09:39.08125] finished run 37/250 for degree_baseline
#
# [2026-03-25 10:09:39.702737] finished run 37/250 for degree_high
#
# [2026-03-25 10:09:40.325559] finished run 37/250 for degree_low
#
# [2026-03-25 10:09:41.11078] finished run 37/250 for degree_random
#
# [2026-03-25 10:09:41.604051] finished run 38/250 for betweenness_baseline
#
# [2026-03-25 10:09:42.394601] finished run 38/250 for betweenness_high
#
# [2026-03-25 10:09:43.016442] finished run 38/250 for betweenness_low
#
# [2026-03-25 10:09:43.643884] finished run 38/250 for betweenness_random
#
# [2026-03-25 10:09:44.149033] finished run 38/250 for degree_baseline
#
# [2026-03-25 10:09:44.783701] finished run 38/250 for degree_high
#
# [2026-03-25 10:09:45.576714] finished run 38/250 for degree_low
#
# [2026-03-25 10:09:46.194013] finished run 38/250 for degree_random
#
# [2026-03-25 10:09:46.699664] finished run 39/250 for betweenness_baseline
#
# [2026-03-25 10:09:47.339638] finished run 39/250 for betweenness_high
#
# [2026-03-25 10:09:48.117682] finished run 39/250 for betweenness_low
#
# [2026-03-25 10:09:48.903187] finished run 39/250 for betweenness_random
#
# [2026-03-25 10:09:49.399068] finished run 39/250 for degree_baseline
#
# [2026-03-25 10:09:50.02754] finished run 39/250 for degree_high
#
# [2026-03-25 10:09:50.651612] finished run 39/250 for degree_low
#
# [2026-03-25 10:09:51.426439] finished run 39/250 for degree_random
#
# [2026-03-25 10:09:51.924061] finished run 40/250 for betweenness_baseline
#
# [2026-03-25 10:09:52.696926] finished run 40/250 for betweenness_high
#
# [2026-03-25 10:09:53.470959] finished run 40/250 for betweenness_low
#
# [2026-03-25 10:09:54.241733] finished run 40/250 for betweenness_random
#
# [2026-03-25 10:09:54.895252] finished run 40/250 for degree_baseline
#
# [2026-03-25 10:09:55.670538] finished run 40/250 for degree_high
#
# [2026-03-25 10:09:56.440738] finished run 40/250 for degree_low
#
# [2026-03-25 10:09:57.212589] finished run 40/250 for degree_random
#
# [2026-03-25 10:09:57.864373] finished run 41/250 for betweenness_baseline
#
# [2026-03-25 10:09:58.47959] finished run 41/250 for betweenness_high
#
# [2026-03-25 10:09:59.106476] finished run 41/250 for betweenness_low
#
# [2026-03-25 10:09:59.744957] finished run 41/250 for betweenness_random
#
# [2026-03-25 10:10:00.39765] finished run 41/250 for degree_baseline
#
# [2026-03-25 10:10:01.03462] finished run 41/250 for degree_high
#
# [2026-03-25 10:10:01.693547] finished run 41/250 for degree_low
#
# [2026-03-25 10:10:02.477607] finished run 41/250 for degree_random
#
# [2026-03-25 10:10:02.976841] finished run 42/250 for betweenness_baseline
#
# [2026-03-25 10:10:03.599578] finished run 42/250 for betweenness_high
#
# [2026-03-25 10:10:04.224459] finished run 42/250 for betweenness_low
#
# [2026-03-25 10:10:05.003571] finished run 42/250 for betweenness_random
#
# [2026-03-25 10:10:05.502034] finished run 42/250 for degree_baseline
#
# [2026-03-25 10:10:06.123363] finished run 42/250 for degree_high
#
# [2026-03-25 10:10:06.901689] finished run 42/250 for degree_low
#
# [2026-03-25 10:10:07.524308] finished run 42/250 for degree_random
#
# [2026-03-25 10:10:08.175742] finished run 43/250 for betweenness_baseline
#
# [2026-03-25 10:10:08.791811] finished run 43/250 for betweenness_high
#
# [2026-03-25 10:10:09.419514] finished run 43/250 for betweenness_low
#
# [2026-03-25 10:10:10.05818] finished run 43/250 for betweenness_random
#
# [2026-03-25 10:10:10.722316] finished run 43/250 for degree_baseline
#
# [2026-03-25 10:10:11.34258] finished run 43/250 for degree_high
#
# [2026-03-25 10:10:11.970881] finished run 43/250 for degree_low
#
# [2026-03-25 10:10:12.746571] finished run 43/250 for degree_random
#
# [2026-03-25 10:10:13.245548] finished run 44/250 for betweenness_baseline
#
# [2026-03-25 10:10:13.871511] finished run 44/250 for betweenness_high
#
# [2026-03-25 10:10:14.650163] finished run 44/250 for betweenness_low
#
# [2026-03-25 10:10:15.270936] finished run 44/250 for betweenness_random
#
# [2026-03-25 10:10:15.768901] finished run 44/250 for degree_baseline
#
# [2026-03-25 10:10:16.398041] finished run 44/250 for degree_high
#
# [2026-03-25 10:10:17.188206] finished run 44/250 for degree_low
#
# [2026-03-25 10:10:17.808885] finished run 44/250 for degree_random
#
# [2026-03-25 10:10:18.308433] finished run 45/250 for betweenness_baseline
#
# [2026-03-25 10:10:19.087523] finished run 45/250 for betweenness_high
#
# [2026-03-25 10:10:19.860855] finished run 45/250 for betweenness_low
#
# [2026-03-25 10:10:20.635528] finished run 45/250 for betweenness_random
#
# [2026-03-25 10:10:21.295279] finished run 45/250 for degree_baseline
#
# [2026-03-25 10:10:22.066669] finished run 45/250 for degree_high
#
# [2026-03-25 10:10:22.839518] finished run 45/250 for degree_low
#
# [2026-03-25 10:10:23.617237] finished run 45/250 for degree_random
#
# [2026-03-25 10:10:24.267809] finished run 46/250 for betweenness_baseline
#
# [2026-03-25 10:10:24.894284] finished run 46/250 for betweenness_high
#
# [2026-03-25 10:10:25.676766] finished run 46/250 for betweenness_low
#
# [2026-03-25 10:10:26.294719] finished run 46/250 for betweenness_random
#
# [2026-03-25 10:10:26.800128] finished run 46/250 for degree_baseline
#
# [2026-03-25 10:10:27.57806] finished run 46/250 for degree_high
#
# [2026-03-25 10:10:28.200551] finished run 46/250 for degree_low
#
# [2026-03-25 10:10:28.825889] finished run 46/250 for degree_random
#
# [2026-03-25 10:10:29.481468] finished run 47/250 for betweenness_baseline
#
# [2026-03-25 10:10:30.101314] finished run 47/250 for betweenness_high
#
# [2026-03-25 10:10:30.747783] finished run 47/250 for betweenness_low
#
# [2026-03-25 10:10:31.537727] finished run 47/250 for betweenness_random
#
# [2026-03-25 10:10:32.038716] finished run 47/250 for degree_baseline
#
# [2026-03-25 10:10:32.666429] finished run 47/250 for degree_high
#
# [2026-03-25 10:10:33.296828] finished run 47/250 for degree_low
#
# [2026-03-25 10:10:34.070768] finished run 47/250 for degree_random
#
# [2026-03-25 10:10:34.567482] finished run 48/250 for betweenness_baseline
#
# [2026-03-25 10:10:35.188707] finished run 48/250 for betweenness_high
#
# [2026-03-25 10:10:35.81473] finished run 48/250 for betweenness_low
#
# [2026-03-25 10:10:36.598965] finished run 48/250 for betweenness_random
#
# [2026-03-25 10:10:37.098883] finished run 48/250 for degree_baseline
#
# [2026-03-25 10:10:37.732935] finished run 48/250 for degree_high
#
# [2026-03-25 10:10:38.511779] finished run 48/250 for degree_low
#
# [2026-03-25 10:10:39.141209] finished run 48/250 for degree_random
#
# [2026-03-25 10:10:39.644141] finished run 49/250 for betweenness_baseline
#
# [2026-03-25 10:10:40.419323] finished run 49/250 for betweenness_high
#
# [2026-03-25 10:10:41.051803] finished run 49/250 for betweenness_low
#
# [2026-03-25 10:10:41.71605] finished run 49/250 for betweenness_random
#
# [2026-03-25 10:10:42.208977] finished run 49/250 for degree_baseline
#
# [2026-03-25 10:10:42.836837] finished run 49/250 for degree_high
#
# [2026-03-25 10:10:43.60969] finished run 49/250 for degree_low
#
# [2026-03-25 10:10:44.230163] finished run 49/250 for degree_random
#
# [2026-03-25 10:10:44.730029] finished run 50/250 for betweenness_baseline
#
# [2026-03-25 10:10:45.504235] finished run 50/250 for betweenness_high
#
# [2026-03-25 10:10:46.278496] finished run 50/250 for betweenness_low
#
# [2026-03-25 10:10:47.049167] finished run 50/250 for betweenness_random
#
# [2026-03-25 10:10:47.703478] finished run 50/250 for degree_baseline
#
# [2026-03-25 10:10:48.483982] finished run 50/250 for degree_high
#
# [2026-03-25 10:10:49.256872] finished run 50/250 for degree_low
#
# [2026-03-25 10:10:50.029971] finished run 50/250 for degree_random
#
# [2026-03-25 10:10:50.682953] finished run 51/250 for betweenness_baseline
#
# [2026-03-25 10:10:51.456926] finished run 51/250 for betweenness_high
#
# [2026-03-25 10:10:52.077409] finished run 51/250 for betweenness_low
#
# [2026-03-25 10:10:52.698012] finished run 51/250 for betweenness_random
#
# [2026-03-25 10:10:53.223991] finished run 51/250 for degree_baseline
#
# [2026-03-25 10:10:53.893308] finished run 51/250 for degree_high
#
# [2026-03-25 10:10:54.674383] finished run 51/250 for degree_low
#
# [2026-03-25 10:10:55.308833] finished run 51/250 for degree_random
#
# [2026-03-25 10:10:55.816112] finished run 52/250 for betweenness_baseline
#
# [2026-03-25 10:10:56.456148] finished run 52/250 for betweenness_high
#
# [2026-03-25 10:10:57.235666] finished run 52/250 for betweenness_low
#
# [2026-03-25 10:10:57.856653] finished run 52/250 for betweenness_random
#
# [2026-03-25 10:10:58.507925] finished run 52/250 for degree_baseline
#
# [2026-03-25 10:10:59.126901] finished run 52/250 for degree_high
#
# [2026-03-25 10:10:59.756979] finished run 52/250 for degree_low
#
# [2026-03-25 10:11:00.388402] finished run 52/250 for degree_random
#
# [2026-03-25 10:11:01.037805] finished run 53/250 for betweenness_baseline
#
# [2026-03-25 10:11:01.658216] finished run 53/250 for betweenness_high
#
# [2026-03-25 10:11:02.290184] finished run 53/250 for betweenness_low
#
# [2026-03-25 10:11:02.919509] finished run 53/250 for betweenness_random
#
# [2026-03-25 10:11:03.435446] finished run 53/250 for degree_baseline
#
# [2026-03-25 10:11:04.21449] finished run 53/250 for degree_high
#
# [2026-03-25 10:11:04.83443] finished run 53/250 for degree_low
#
# [2026-03-25 10:11:05.489318] finished run 53/250 for degree_random
#
# [2026-03-25 10:11:05.983705] finished run 54/250 for betweenness_baseline
#
# [2026-03-25 10:11:06.613105] finished run 54/250 for betweenness_high
#
# [2026-03-25 10:11:07.38773] finished run 54/250 for betweenness_low
#
# [2026-03-25 10:11:08.010481] finished run 54/250 for betweenness_random
#
# [2026-03-25 10:11:08.662898] finished run 54/250 for degree_baseline
#
# [2026-03-25 10:11:09.279222] finished run 54/250 for degree_high
#
# [2026-03-25 10:11:09.909083] finished run 54/250 for degree_low
#
# [2026-03-25 10:11:10.537332] finished run 54/250 for degree_random
#
# [2026-03-25 10:11:11.197922] finished run 55/250 for betweenness_baseline
#
# [2026-03-25 10:11:11.971305] finished run 55/250 for betweenness_high
#
# [2026-03-25 10:11:12.746708] finished run 55/250 for betweenness_low
#
# [2026-03-25 10:11:13.518368] finished run 55/250 for betweenness_random
#
# [2026-03-25 10:11:14.16929] finished run 55/250 for degree_baseline
#
# [2026-03-25 10:11:14.938522] finished run 55/250 for degree_high
#
# [2026-03-25 10:11:15.715613] finished run 55/250 for degree_low
#
# [2026-03-25 10:11:16.490326] finished run 55/250 for degree_random
#
# [2026-03-25 10:11:17.143356] finished run 56/250 for betweenness_baseline
#
# [2026-03-25 10:11:17.761962] finished run 56/250 for betweenness_high
#
# [2026-03-25 10:11:18.387943] finished run 56/250 for betweenness_low
#
# [2026-03-25 10:11:19.016135] finished run 56/250 for betweenness_random
#
# [2026-03-25 10:11:19.666155] finished run 56/250 for degree_baseline
#
# [2026-03-25 10:11:20.440718] finished run 56/250 for degree_high
#
# [2026-03-25 10:11:21.061882] finished run 56/250 for degree_low
#
# [2026-03-25 10:11:21.683187] finished run 56/250 for degree_random
#
# [2026-03-25 10:11:22.186899] finished run 57/250 for betweenness_baseline
#
# [2026-03-25 10:11:22.820004] finished run 57/250 for betweenness_high
#
# [2026-03-25 10:11:23.606162] finished run 57/250 for betweenness_low
#
# [2026-03-25 10:11:24.222391] finished run 57/250 for betweenness_random
#
# [2026-03-25 10:11:24.883945] finished run 57/250 for degree_baseline
#
# [2026-03-25 10:11:25.503927] finished run 57/250 for degree_high
#
# [2026-03-25 10:11:26.128476] finished run 57/250 for degree_low
#
# [2026-03-25 10:11:26.909605] finished run 57/250 for degree_random
#
# [2026-03-25 10:11:27.408358] finished run 58/250 for betweenness_baseline
#
# [2026-03-25 10:11:28.039867] finished run 58/250 for betweenness_high
#
# [2026-03-25 10:11:28.676022] finished run 58/250 for betweenness_low
#
# [2026-03-25 10:11:29.463548] finished run 58/250 for betweenness_random
#
# [2026-03-25 10:11:29.963012] finished run 58/250 for degree_baseline
#
# [2026-03-25 10:11:30.591021] finished run 58/250 for degree_high
#
# [2026-03-25 10:11:31.368768] finished run 58/250 for degree_low
#
# [2026-03-25 10:11:31.990953] finished run 58/250 for degree_random
#
# [2026-03-25 10:11:32.652975] finished run 59/250 for betweenness_baseline
#
# [2026-03-25 10:11:33.276333] finished run 59/250 for betweenness_high
#
# [2026-03-25 10:11:33.916527] finished run 59/250 for betweenness_low
#
# [2026-03-25 10:11:34.554253] finished run 59/250 for betweenness_random
#
# [2026-03-25 10:11:35.208755] finished run 59/250 for degree_baseline
#
# [2026-03-25 10:11:35.83114] finished run 59/250 for degree_high
#
# [2026-03-25 10:11:36.470772] finished run 59/250 for degree_low
#
# [2026-03-25 10:11:37.101896] finished run 59/250 for degree_random
#
# [2026-03-25 10:11:37.61122] finished run 60/250 for betweenness_baseline
#
# [2026-03-25 10:11:38.390511] finished run 60/250 for betweenness_high
#
# [2026-03-25 10:11:39.166501] finished run 60/250 for betweenness_low
#
# [2026-03-25 10:11:39.941982] finished run 60/250 for betweenness_random
#
# [2026-03-25 10:11:40.594994] finished run 60/250 for degree_baseline
#
# [2026-03-25 10:11:41.367232] finished run 60/250 for degree_high
#
# [2026-03-25 10:11:42.165475] finished run 60/250 for degree_low
#
# [2026-03-25 10:11:42.950949] finished run 60/250 for degree_random
#
# [2026-03-25 10:11:43.605231] finished run 61/250 for betweenness_baseline
#
# [2026-03-25 10:11:44.221269] finished run 61/250 for betweenness_high
#
# [2026-03-25 10:11:44.998881] finished run 61/250 for betweenness_low
#
# [2026-03-25 10:11:45.626704] finished run 61/250 for betweenness_random
#
# [2026-03-25 10:11:46.138804] finished run 61/250 for degree_baseline
#
# [2026-03-25 10:11:46.957543] finished run 61/250 for degree_high
#
# [2026-03-25 10:11:47.57866] finished run 61/250 for degree_low
#
# [2026-03-25 10:11:48.204584] finished run 61/250 for degree_random
#
# [2026-03-25 10:11:48.71566] finished run 62/250 for betweenness_baseline
#
# [2026-03-25 10:11:49.500882] finished run 62/250 for betweenness_high
#
# [2026-03-25 10:11:50.123501] finished run 62/250 for betweenness_low
#
# [2026-03-25 10:11:50.906043] finished run 62/250 for betweenness_random
#
# [2026-03-25 10:11:51.404695] finished run 62/250 for degree_baseline
#
# [2026-03-25 10:11:52.029876] finished run 62/250 for degree_high
#
# [2026-03-25 10:11:52.660676] finished run 62/250 for degree_low
#
# [2026-03-25 10:11:53.455288] finished run 62/250 for degree_random
#
# [2026-03-25 10:11:53.95422] finished run 63/250 for betweenness_baseline
#
# [2026-03-25 10:11:54.572984] finished run 63/250 for betweenness_high
#
# [2026-03-25 10:11:55.36692] finished run 63/250 for betweenness_low
#
# [2026-03-25 10:11:55.989341] finished run 63/250 for betweenness_random
#
# [2026-03-25 10:11:56.647695] finished run 63/250 for degree_baseline
#
# [2026-03-25 10:11:57.265324] finished run 63/250 for degree_high
#
# [2026-03-25 10:11:57.919006] finished run 63/250 for degree_low
#
# [2026-03-25 10:11:58.54845] finished run 63/250 for degree_random
#
# [2026-03-25 10:11:59.213221] finished run 64/250 for betweenness_baseline
#
# [2026-03-25 10:11:59.82865] finished run 64/250 for betweenness_high
#
# [2026-03-25 10:12:00.457707] finished run 64/250 for betweenness_low
#
# [2026-03-25 10:12:01.241616] finished run 64/250 for betweenness_random
#
# [2026-03-25 10:12:01.735623] finished run 64/250 for degree_baseline
#
# [2026-03-25 10:12:02.358501] finished run 64/250 for degree_high
#
# [2026-03-25 10:12:03.141068] finished run 64/250 for degree_low
#
# [2026-03-25 10:12:03.770295] finished run 64/250 for degree_random
#
# [2026-03-25 10:12:04.269558] finished run 65/250 for betweenness_baseline
#
# [2026-03-25 10:12:05.048435] finished run 65/250 for betweenness_high
#
# [2026-03-25 10:12:05.826566] finished run 65/250 for betweenness_low
#
# [2026-03-25 10:12:06.598696] finished run 65/250 for betweenness_random
#
# [2026-03-25 10:12:07.253911] finished run 65/250 for degree_baseline
#
# [2026-03-25 10:12:08.027927] finished run 65/250 for degree_high
#
# [2026-03-25 10:12:08.80439] finished run 65/250 for degree_low
#
# [2026-03-25 10:12:09.583697] finished run 65/250 for degree_random
#
# [2026-03-25 10:12:10.238592] finished run 66/250 for betweenness_baseline
#
# [2026-03-25 10:12:10.855901] finished run 66/250 for betweenness_high
#
# [2026-03-25 10:12:11.493498] finished run 66/250 for betweenness_low
#
# [2026-03-25 10:12:12.123995] finished run 66/250 for betweenness_random
#
# [2026-03-25 10:12:12.781829] finished run 66/250 for degree_baseline
#
# [2026-03-25 10:12:13.401923] finished run 66/250 for degree_high
#
# [2026-03-25 10:12:14.028855] finished run 66/250 for degree_low
#
# [2026-03-25 10:12:14.807073] finished run 66/250 for degree_random
#
# [2026-03-25 10:12:15.305708] finished run 67/250 for betweenness_baseline
#
# [2026-03-25 10:12:15.932719] finished run 67/250 for betweenness_high
#
# [2026-03-25 10:12:16.710859] finished run 67/250 for betweenness_low
#
# [2026-03-25 10:12:17.329737] finished run 67/250 for betweenness_random
#
# [2026-03-25 10:12:17.855266] finished run 67/250 for degree_baseline
#
# [2026-03-25 10:12:18.480683] finished run 67/250 for degree_high
#
# [2026-03-25 10:12:19.256452] finished run 67/250 for degree_low
#
# [2026-03-25 10:12:19.874686] finished run 67/250 for degree_random
#
# [2026-03-25 10:12:20.375048] finished run 68/250 for betweenness_baseline
#
# [2026-03-25 10:12:20.999459] finished run 68/250 for betweenness_high
#
# [2026-03-25 10:12:21.779661] finished run 68/250 for betweenness_low
#
# [2026-03-25 10:12:22.402078] finished run 68/250 for betweenness_random
#
# [2026-03-25 10:12:22.898072] finished run 68/250 for degree_baseline
#
# [2026-03-25 10:12:23.680612] finished run 68/250 for degree_high
#
# [2026-03-25 10:12:24.296327] finished run 68/250 for degree_low
#
# [2026-03-25 10:12:24.920944] finished run 68/250 for degree_random
#
# [2026-03-25 10:12:25.41984] finished run 69/250 for betweenness_baseline
#
# [2026-03-25 10:12:26.057875] finished run 69/250 for betweenness_high
#
# [2026-03-25 10:12:26.834705] finished run 69/250 for betweenness_low
#
# [2026-03-25 10:12:27.456652] finished run 69/250 for betweenness_random
#
# [2026-03-25 10:12:27.959215] finished run 69/250 for degree_baseline
#
# [2026-03-25 10:12:28.581813] finished run 69/250 for degree_high
#
# [2026-03-25 10:12:29.357091] finished run 69/250 for degree_low
#
# [2026-03-25 10:12:29.97664] finished run 69/250 for degree_random
#
# [2026-03-25 10:12:30.502489] finished run 70/250 for betweenness_baseline
#
# [2026-03-25 10:12:31.274014] finished run 70/250 for betweenness_high
#
# [2026-03-25 10:12:32.049634] finished run 70/250 for betweenness_low
#
# [2026-03-25 10:12:32.827437] finished run 70/250 for betweenness_random
#
# [2026-03-25 10:12:33.47894] finished run 70/250 for degree_baseline
#
# [2026-03-25 10:12:34.265139] finished run 70/250 for degree_high
#
# [2026-03-25 10:12:35.041276] finished run 70/250 for degree_low
#
# [2026-03-25 10:12:35.817926] finished run 70/250 for degree_random
#
# [2026-03-25 10:12:36.473888] finished run 71/250 for betweenness_baseline
#
# [2026-03-25 10:12:37.094168] finished run 71/250 for betweenness_high
#
# [2026-03-25 10:12:37.719808] finished run 71/250 for betweenness_low
#
# [2026-03-25 10:12:38.348171] finished run 71/250 for betweenness_random
#
# [2026-03-25 10:12:39.014805] finished run 71/250 for degree_baseline
#
# [2026-03-25 10:12:39.645526] finished run 71/250 for degree_high
#
# [2026-03-25 10:12:40.296417] finished run 71/250 for degree_low
#
# [2026-03-25 10:12:41.069031] finished run 71/250 for degree_random
#
# [2026-03-25 10:12:41.568237] finished run 72/250 for betweenness_baseline
#
# [2026-03-25 10:12:42.20563] finished run 72/250 for betweenness_high
#
# [2026-03-25 10:12:42.834453] finished run 72/250 for betweenness_low
#
# [2026-03-25 10:12:43.467525] finished run 72/250 for betweenness_random
#
# [2026-03-25 10:12:44.12424] finished run 72/250 for degree_baseline
#
# [2026-03-25 10:12:44.745733] finished run 72/250 for degree_high
#
# [2026-03-25 10:12:45.535255] finished run 72/250 for degree_low
#
# [2026-03-25 10:12:46.154546] finished run 72/250 for degree_random
#
# [2026-03-25 10:12:46.659908] finished run 73/250 for betweenness_baseline
#
# [2026-03-25 10:12:47.454523] finished run 73/250 for betweenness_high
#
# [2026-03-25 10:12:48.234554] finished run 73/250 for betweenness_low
#
# [2026-03-25 10:12:48.854068] finished run 73/250 for betweenness_random
#
# [2026-03-25 10:12:49.431769] finished run 73/250 for degree_baseline
#
# [2026-03-25 10:12:50.058103] finished run 73/250 for degree_high
#
# [2026-03-25 10:12:50.856944] finished run 73/250 for degree_low
#
# [2026-03-25 10:12:51.479729] finished run 73/250 for degree_random
#
# [2026-03-25 10:12:51.985853] finished run 74/250 for betweenness_baseline
#
# [2026-03-25 10:12:52.617951] finished run 74/250 for betweenness_high
#
# [2026-03-25 10:12:53.253359] finished run 74/250 for betweenness_low
#
# [2026-03-25 10:12:54.040457] finished run 74/250 for betweenness_random
#
# [2026-03-25 10:12:54.540385] finished run 74/250 for degree_baseline
#
# [2026-03-25 10:12:55.171298] finished run 74/250 for degree_high
#
# [2026-03-25 10:12:55.796995] finished run 74/250 for degree_low
#
# [2026-03-25 10:12:56.432563] finished run 74/250 for degree_random
#
# [2026-03-25 10:12:56.94404] finished run 75/250 for betweenness_baseline
#
# [2026-03-25 10:12:57.735802] finished run 75/250 for betweenness_high
#
# [2026-03-25 10:12:58.530254] finished run 75/250 for betweenness_low
#
# [2026-03-25 10:12:59.315136] finished run 75/250 for betweenness_random
#
# [2026-03-25 10:12:59.976748] finished run 75/250 for degree_baseline
#
# [2026-03-25 10:13:00.765736] finished run 75/250 for degree_high
#
# [2026-03-25 10:13:01.553076] finished run 75/250 for degree_low
#
# [2026-03-25 10:13:02.34059] finished run 75/250 for degree_random
#
# [2026-03-25 10:13:03.00899] finished run 76/250 for betweenness_baseline
#
# [2026-03-25 10:13:03.652704] finished run 76/250 for betweenness_high
#
# [2026-03-25 10:13:04.286456] finished run 76/250 for betweenness_low
#
# [2026-03-25 10:13:04.934033] finished run 76/250 for betweenness_random
#
# [2026-03-25 10:13:05.601929] finished run 76/250 for degree_baseline
#
# [2026-03-25 10:13:06.227445] finished run 76/250 for degree_high
#
# [2026-03-25 10:13:06.863153] finished run 76/250 for degree_low
#
# [2026-03-25 10:13:07.655133] finished run 76/250 for degree_random
#
# [2026-03-25 10:13:08.159569] finished run 77/250 for betweenness_baseline
#
# [2026-03-25 10:13:08.785769] finished run 77/250 for betweenness_high
#
# [2026-03-25 10:13:09.431922] finished run 77/250 for betweenness_low
#
# [2026-03-25 10:13:10.238472] finished run 77/250 for betweenness_random
#
# [2026-03-25 10:13:10.742306] finished run 77/250 for degree_baseline
#
# [2026-03-25 10:13:11.366218] finished run 77/250 for degree_high
#
# [2026-03-25 10:13:12.16793] finished run 77/250 for degree_low
#
# [2026-03-25 10:13:12.793689] finished run 77/250 for degree_random
#
# [2026-03-25 10:13:13.30135] finished run 78/250 for betweenness_baseline
#
# [2026-03-25 10:13:14.102559] finished run 78/250 for betweenness_high
#
# [2026-03-25 10:13:14.724264] finished run 78/250 for betweenness_low
#
# [2026-03-25 10:13:15.356907] finished run 78/250 for betweenness_random
#
# [2026-03-25 10:13:16.032574] finished run 78/250 for degree_baseline
#
# [2026-03-25 10:13:16.657698] finished run 78/250 for degree_high
#
# [2026-03-25 10:13:17.442785] finished run 78/250 for degree_low
#
# [2026-03-25 10:13:18.062367] finished run 78/250 for degree_random
#
# [2026-03-25 10:13:18.583824] finished run 79/250 for betweenness_baseline
#
# [2026-03-25 10:13:19.207571] finished run 79/250 for betweenness_high
#
# [2026-03-25 10:13:19.852473] finished run 79/250 for betweenness_low
#
# [2026-03-25 10:13:20.639123] finished run 79/250 for betweenness_random
#
# [2026-03-25 10:13:21.138268] finished run 79/250 for degree_baseline
#
# [2026-03-25 10:13:21.767004] finished run 79/250 for degree_high
#
# [2026-03-25 10:13:22.548792] finished run 79/250 for degree_low
#
# [2026-03-25 10:13:23.172521] finished run 79/250 for degree_random
#
# [2026-03-25 10:13:23.834822] finished run 80/250 for betweenness_baseline
#
# [2026-03-25 10:13:24.611412] finished run 80/250 for betweenness_high
#
# [2026-03-25 10:13:25.392102] finished run 80/250 for betweenness_low
#
# [2026-03-25 10:13:26.166023] finished run 80/250 for betweenness_random
#
# [2026-03-25 10:13:26.820505] finished run 80/250 for degree_baseline
#
# [2026-03-25 10:13:27.595213] finished run 80/250 for degree_high
#
# [2026-03-25 10:13:28.373096] finished run 80/250 for degree_low
#
# [2026-03-25 10:13:29.150145] finished run 80/250 for degree_random
#
# [2026-03-25 10:13:29.805286] finished run 81/250 for betweenness_baseline
#
# [2026-03-25 10:13:30.422777] finished run 81/250 for betweenness_high
#
# [2026-03-25 10:13:31.052187] finished run 81/250 for betweenness_low
#
# [2026-03-25 10:13:31.685632] finished run 81/250 for betweenness_random
#
# [2026-03-25 10:13:32.350035] finished run 81/250 for degree_baseline
#
# [2026-03-25 10:13:32.972224] finished run 81/250 for degree_high
#
# [2026-03-25 10:13:33.624205] finished run 81/250 for degree_low
#
# [2026-03-25 10:13:34.402458] finished run 81/250 for degree_random
#
# [2026-03-25 10:13:34.90438] finished run 82/250 for betweenness_baseline
#
# [2026-03-25 10:13:35.702305] finished run 82/250 for betweenness_high
#
# [2026-03-25 10:13:36.320227] finished run 82/250 for betweenness_low
#
# [2026-03-25 10:13:36.948761] finished run 82/250 for betweenness_random
#
# [2026-03-25 10:13:37.635486] finished run 82/250 for degree_baseline
#
# [2026-03-25 10:13:38.253063] finished run 82/250 for degree_high
#
# [2026-03-25 10:13:38.885047] finished run 82/250 for degree_low
#
# [2026-03-25 10:13:39.517775] finished run 82/250 for degree_random
#
# [2026-03-25 10:13:40.173917] finished run 83/250 for betweenness_baseline
#
# [2026-03-25 10:13:40.952246] finished run 83/250 for betweenness_high
#
# [2026-03-25 10:13:41.568868] finished run 83/250 for betweenness_low
#
# [2026-03-25 10:13:42.205009] finished run 83/250 for betweenness_random
#
# [2026-03-25 10:13:42.704878] finished run 83/250 for degree_baseline
#
# [2026-03-25 10:13:43.477965] finished run 83/250 for degree_high
#
# [2026-03-25 10:13:44.101191] finished run 83/250 for degree_low
#
# [2026-03-25 10:13:44.734617] finished run 83/250 for degree_random
#
# [2026-03-25 10:13:45.24538] finished run 84/250 for betweenness_baseline
#
# [2026-03-25 10:13:45.880184] finished run 84/250 for betweenness_high
#
# [2026-03-25 10:13:46.673824] finished run 84/250 for betweenness_low
#
# [2026-03-25 10:13:47.30332] finished run 84/250 for betweenness_random
#
# [2026-03-25 10:13:47.815583] finished run 84/250 for degree_baseline
#
# [2026-03-25 10:13:48.604761] finished run 84/250 for degree_high
#
# [2026-03-25 10:13:49.234132] finished run 84/250 for degree_low
#
# [2026-03-25 10:13:50.021365] finished run 84/250 for degree_random
#
# [2026-03-25 10:13:50.527195] finished run 85/250 for betweenness_baseline
#
# [2026-03-25 10:13:51.317166] finished run 85/250 for betweenness_high
#
# [2026-03-25 10:13:52.114024] finished run 85/250 for betweenness_low
#
# [2026-03-25 10:13:52.896443] finished run 85/250 for betweenness_random
#
# [2026-03-25 10:13:53.554056] finished run 85/250 for degree_baseline
#
# [2026-03-25 10:13:54.339523] finished run 85/250 for degree_high
#
# [2026-03-25 10:13:55.122769] finished run 85/250 for degree_low
#
# [2026-03-25 10:13:55.920819] finished run 85/250 for degree_random
#
# [2026-03-25 10:13:56.581982] finished run 86/250 for betweenness_baseline
#
# [2026-03-25 10:13:57.240561] finished run 86/250 for betweenness_high
#
# [2026-03-25 10:13:57.881508] finished run 86/250 for betweenness_low
#
# [2026-03-25 10:13:58.53694] finished run 86/250 for betweenness_random
#
# [2026-03-25 10:13:59.06127] finished run 86/250 for degree_baseline
#
# [2026-03-25 10:13:59.721866] finished run 86/250 for degree_high
#
# [2026-03-25 10:14:00.514726] finished run 86/250 for degree_low
#
# [2026-03-25 10:14:01.142231] finished run 86/250 for degree_random
#
# [2026-03-25 10:14:01.646861] finished run 87/250 for betweenness_baseline
#
# [2026-03-25 10:14:02.272698] finished run 87/250 for betweenness_high
#
# [2026-03-25 10:14:03.071039] finished run 87/250 for betweenness_low
#
# [2026-03-25 10:14:03.694722] finished run 87/250 for betweenness_random
#
# [2026-03-25 10:14:04.197075] finished run 87/250 for degree_baseline
#
# [2026-03-25 10:14:04.843311] finished run 87/250 for degree_high
#
# [2026-03-25 10:14:05.487396] finished run 87/250 for degree_low
#
# [2026-03-25 10:14:06.259834] finished run 87/250 for degree_random
#
# [2026-03-25 10:14:06.76096] finished run 88/250 for betweenness_baseline
#
# [2026-03-25 10:14:07.383279] finished run 88/250 for betweenness_high
#
# [2026-03-25 10:14:08.010818] finished run 88/250 for betweenness_low
#
# [2026-03-25 10:14:08.788311] finished run 88/250 for betweenness_random
#
# [2026-03-25 10:14:09.286887] finished run 88/250 for degree_baseline
#
# [2026-03-25 10:14:09.917033] finished run 88/250 for degree_high
#
# [2026-03-25 10:14:10.696602] finished run 88/250 for degree_low
#
# [2026-03-25 10:14:11.318649] finished run 88/250 for degree_random
#
# [2026-03-25 10:14:11.822618] finished run 89/250 for betweenness_baseline
#
# [2026-03-25 10:14:12.612079] finished run 89/250 for betweenness_high
#
# [2026-03-25 10:14:13.233193] finished run 89/250 for betweenness_low
#
# [2026-03-25 10:14:13.860838] finished run 89/250 for betweenness_random
#
# [2026-03-25 10:14:14.365678] finished run 89/250 for degree_baseline
#
# [2026-03-25 10:14:15.154588] finished run 89/250 for degree_high
#
# [2026-03-25 10:14:15.777309] finished run 89/250 for degree_low
#
# [2026-03-25 10:14:16.406593] finished run 89/250 for degree_random
#
# [2026-03-25 10:14:17.06159] finished run 90/250 for betweenness_baseline
#
# [2026-03-25 10:14:17.836252] finished run 90/250 for betweenness_high
#
# [2026-03-25 10:14:18.609743] finished run 90/250 for betweenness_low
#
# [2026-03-25 10:14:19.384576] finished run 90/250 for betweenness_random
#
# [2026-03-25 10:14:20.037688] finished run 90/250 for degree_baseline
#
# [2026-03-25 10:14:20.820341] finished run 90/250 for degree_high
#
# [2026-03-25 10:14:21.594276] finished run 90/250 for degree_low

# %%
# INLINE FIGURE ONLY - SHARE OF TREATED OFFTAKERS BY SECTOR
#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------


# sector totals
sector_totals <- offtakers %>%
  as.data.frame() %>%
  count(sector, name = "n_total")

# treated by sector and scenario
treated_by_sector <- purrr::map_dfr(
  names(results_all),
  function(key) {

    tr <- results_all[[key]]$treated_offtakers
    if (is.null(tr)) return(NULL)

    tr %>%
      filter(treated) %>%
      count(sector, name = "n_treated") %>%
      mutate(scenario = key)
  }
)

# assign centrality and intervention
treated_by_sector <- treated_by_sector %>%
  mutate(
    centrality_type = case_when(
      grepl("^betweenness_", scenario) ~ "Betweenness",
      grepl("^degree_", scenario) ~ "Degree",
      TRUE ~ NA_character_
    ),
    intervention = case_when(
      grepl("_high$", scenario) ~ "High Centrality",
      grepl("_low$", scenario) ~ "Low Centrality",
      grepl("_random$", scenario) ~ "Cost-only",
      TRUE ~ NA_character_
    )
  ) %>%
  filter(!is.na(intervention))

# join totals and compute share
treated_by_sector <- treated_by_sector %>%
  left_join(sector_totals, by = "sector") %>%
  mutate(
    share_treated = n_treated / n_total,
    intervention = factor(
      intervention,
      levels = c("Cost-only", "Low Centrality", "High Centrality")
    )
  )

# plot counts
p_counts <- ggplot(
  treated_by_sector,
  aes(x = sector, y = n_treated, fill = intervention)
) +
  geom_col(position = position_dodge(width = 0.85), width = 0.8) +
  facet_wrap(~ centrality_type, nrow = 1) +
  labs(
    x = NULL,
    y = "Number of treated installations",
    fill = NULL
  ) +
  theme_minimal(base_size = 20) +
  theme(
    axis.text.x = element_text(angle = 45, hjust = 1),
    panel.grid = element_blank()
  )

print(p_counts)

# plot shares
p_share <- ggplot(
  treated_by_sector,
  aes(x = sector, y = share_treated, fill = intervention)
) +
  geom_col(position = position_dodge(width = 0.85), width = 0.8) +
  facet_wrap(~ centrality_type, nrow = 1) +
  scale_y_continuous(labels = scales::percent_format(accuracy = 1)) +
  labs(
    x = NULL,
    y = "Share of installations targeted (%)",
    fill = NULL
  ) +
  theme_minimal(base_size = 20) +
  theme(
    axis.text.x = element_text(angle = 45, hjust = 1),
    panel.grid = element_blank()
  )

print(p_share)
