# %%
#SIMULATION - POLICY INTERVENTION (Readme)
#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# Module conducts the following analysis:

# ---- Policy intervention simulation

# Module is input for:

# ---- Simulation-policy-effectiveness#
# ---- Simulation-treatment

# %%
#SET-UP
#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
setwd("/home/h1604190/Spatially-informed Demand-side Policies for Green H2 Diffusion/") 
check_and_load <- function(packages) {
  for (pkg in packages) {
    if (!requireNamespace(pkg, quietly = TRUE)) {
      message(paste("Installing missing package:", pkg))
      install.packages(pkg, dependencies = TRUE, repos = "https://cloud.r-project.org")
    }
    if (!(pkg %in% (.packages()))) {
      suppressPackageStartupMessages(library(pkg, character.only = TRUE))
    }
  }
}

# --- Required Libraries ---
required_packages <- c(
  "dplyr",    # data manipulation (mutate, group_by, summarise, etc.)
  "Matrix",   # sparse matrix operations for spatial weights
  "FNN",      # k-nearest neighbors (get.knnx for adjacency matrix)
  "sf",       # spatial features (for coordinates, distances, geometry ops)
  "tidyr",    # tidy reshaping, replace_na
  "tibble"    # tibbles
)

check_and_load(required_packages)

# %%
#INPUTS AND SETTINGS
#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# --- Calibration Parameters ---
distance_cutoff_rotterdam <- 50000           # [m] Max distance for seeding initial adopters around Rotterdam
rotterdam_coords <- cbind(4.4786, 51.9244)   # Rotterdam coordinates (reference point for initialization)
start_year <- 1961                           # Start year of diffusion in calibration set
noise_multiplier <- 0.5                      # Noise multiplier for second-pass calibration (to avoid overfitting)
k_max_number <- 500                          # Max number of neighbors for KNN spatial weights
km_cutoff <- 120000                          # [m] Distance cutoff for adjacency matrix (optimized in calibration)

# --- Simulation Parameters ---
initial_share <- 0.01                        # Share of adopters at start of simulation (as fraction of eligible offtakers)
carbon_price_setting <- "carbon_price"       # Fossil scenario: "carbon_price", "flat_carbon_price", or "no_carbon_price"
n_simulations <- 100                        # Number of Monte Carlo simulation runs
start_year_sim <- 2024                       # Start year for prospective simulation
end_year <- 2100                             # End year for prospective simulation
intervention_volume <- 0.1                   # Fraction of plants targeted per sector-quantile group
quantile <- 4                                # Sectoral stratification granularity (quartiles)
seeds <- 1:n_simulations                     # reproducibility
saturation_setting <- "central"              # switch to "restricted" / "extended" if needed
cost_setting <- "mean"                       # switch to conservative / progressive if needed
simulation_years <- start_year_sim:end_year

# %%
# DATA FILES
#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
offtakers <- readRDS("offtakers_centrality.rds")
cost_gap_data <- readRDS("cost_gap_data.rds")
spatial_weights <- readRDS("spatial_weights.rds")

# %%
# HELPER FUNCTIONS
#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

filter_intervention_group <- function(df_group, type, k, seed) {
  if (type == "high") {
    slice_head(arrange(df_group, desc(contribution)), n = k)

  } else if (type == "low") {
    slice_head(arrange(df_group, contribution), n = k)

  } else {
    withr::with_seed(seed, slice_sample(df_group, n = k))
  }
}

summarize_run <- function(run_result) {
  run_result$adoption_plant %>%
    left_join(run_result$policy_cost, by = c("year", "plant_id")) %>%
    group_by(year) %>%
    summarise(
      annual_demand = sum(adoption * hydrogen_2050, na.rm = TRUE),
      annual_cost   = sum(policy_cost, na.rm = TRUE),
      .groups = "drop"
    )
}


  adopt_prob <- function(beta0, beta1, spatial_influence_detrended,
                       beta2, cost_diff,
                       beta3, distance_to_waterway,
                       beta4, distance_to_pipeline,
                       beta5) {
  1 / (1 + exp(-(beta0 +
                 beta1 * spatial_influence_detrended +
                 beta2 * cost_diff +
                 beta3 * distance_to_waterway +
                 beta4 * distance_to_pipeline +
                 beta5 * spatial_influence_detrended * cost_diff)))
}

# %%
# policy simulation
offtakers_df <- offtakers %>%
  st_set_geometry(NULL) %>%
  mutate(beta6 = get(paste0("beta6_", saturation_setting))) %>%
  select(
    plant_id, sector, hydrogen_2050,
    beta0, beta1, beta2, beta3, beta4, beta5, beta6,
    distance_to_rotterdam, distance_to_waterway, distance_to_pipeline,
    betweenness, degree
  )

# core vectors
sector <- offtakers_df$sector
plant_id <- offtakers_df$plant_id
n_offtakers <- nrow(offtakers_df)
unique_sectors <- unique(sector)

beta0_vec <- offtakers_df$beta0
beta1_vec <- offtakers_df$beta1
beta2_vec <- offtakers_df$beta2
beta3_vec <- offtakers_df$beta3
beta4_vec <- offtakers_df$beta4
beta5_vec <- offtakers_df$beta5
beta6_vec <- offtakers_df$beta6

distance_rotterdam <- offtakers_df$distance_to_rotterdam
distance_waterway <- offtakers_df$distance_to_waterway
distance_pipeline <- offtakers_df$distance_to_pipeline
hydrogen_2050 <- offtakers_df$hydrogen_2050

# sector structure
sector_index <- split(seq_len(n_offtakers), sector)
sector_factor <- as.integer(factor(sector, levels = unique_sectors))
n_sectors <- length(unique_sectors)
sector_counts <- tabulate(sector_factor, nbins = n_sectors)

# cost lookup
cost_diff_lookup <- cost_gap_data %>%
  filter(
    green_scenario == cost_setting,
    fossil_scenario == carbon_price_setting
  ) %>%
  select(year, sector, cost_diff) %>%
  distinct(year, sector, .keep_all = TRUE) %>%
  mutate(sector = as.character(sector)) %>%
  split(.$year)

# intervention settings
centrality_types <- list(
  betweenness = offtakers_df$betweenness,
  degree = offtakers_df$degree
)

intervention_types <- c("baseline", "high", "low", "random")

# initial adopters
eligible_init <- which(
  distance_rotterdam <= distance_cutoff_rotterdam &
    beta6_vec > 0
)

set.seed(42)

selected_indices <- if (length(eligible_init) > 0) {
  sample(
    eligible_init,
    size = min(length(eligible_init), max(1, round(initial_share * length(eligible_init)))),
    replace = FALSE
  )
} else {
  integer(0)
}

initial_adoption <- rep.int(0, n_offtakers)
initial_adoption[selected_indices] <- 1

# simulation function
run_simulation <- function(intervention_type = "baseline",
                           seed = 19,
                           contribution_score) {

  set.seed(seed)

  # time setup
  years <- simulation_years
  n_years <- length(years)

  # storage
  adoption_mat <- matrix(0, n_offtakers, n_years)
  cost_diff_mat <- matrix(0, n_offtakers, n_years)
  original_cost_diff_mat <- matrix(0, n_offtakers, n_years)
  policy_cost_mat <- matrix(0, n_offtakers, n_years)

  influence_summary_list <- vector("list", n_years)
  influence_plant_list <- vector("list", n_years)

  # stratification
  stratification_df <- tibble(
    idx = seq_len(n_offtakers),
    sector = sector,
    hydrogen_2050 = hydrogen_2050,
    contribution = contribution_score
  ) %>%
    filter(!is.na(contribution)) %>%
    group_by(sector) %>%
    mutate(quant_group = ntile(hydrogen_2050, !!quantile)) %>%
    ungroup()

  target_offtakers <- integer(0)

  # treated group
  if (intervention_type != "baseline") {
    targeted_df <- stratification_df %>%
      group_by(sector, quant_group) %>%
      group_modify(~ {
        k <- ceiling(intervention_volume * nrow(.x))
        filter_intervention_group(.x, intervention_type, k, seed)
      }) %>%
      ungroup()

    target_offtakers <- targeted_df$idx
  }

  treated_flag_vec <- logical(n_offtakers)
  treated_flag_vec[target_offtakers] <- TRUE

  # treatment summary
  sector_quantile_summary <- NULL
  if (length(target_offtakers)) {
    sector_quantile_summary <- stratification_df %>%
      mutate(
        targeted = if_else(idx %in% target_offtakers, intervention_type, "none")
      ) %>%
      group_by(sector, quant_group, targeted) %>%
      summarise(
        mean_contribution = mean(contribution),
        mean_hydrogen_2050 = mean(hydrogen_2050),
        n_plants = n(),
        .groups = "drop"
      )
  }

  # sector types
  previous_adoption <- initial_adoption

  continuous_sectors <- c("Heavy duty", "Aviation", "Shipping")
  continuous_flag <- sector %in% continuous_sectors
  discrete_sectors <- unique_sectors[!unique_sectors %in% continuous_sectors]

  # simulation loop
  for (tt in seq_len(n_years)) {
    year <- years[tt]

    # spatial influence
    spatial_influence <- as.numeric(spatial_weights %*% previous_adoption)
    spatial_influence[is.na(spatial_influence)] <- 0
    spatial_influence_detrended <- spatial_influence - mean(spatial_influence)

    # influence outputs
    if (length(target_offtakers)) {
      influence_summary_list[[tt]] <- tibble(
        year = year,
        treated_influence_received = sum(spatial_influence[treated_flag_vec]),
        untreated_influence_received = sum(spatial_influence[!treated_flag_vec]),
        mean_adoption_treated = mean(previous_adoption[treated_flag_vec]),
        mean_adoption_untreated = mean(previous_adoption[!treated_flag_vec])
      )

      influence_plant_list[[tt]] <- tibble(
        year = year,
        plant_id = plant_id,
        spatial_influence = spatial_influence,
        treated = treated_flag_vec
      )
    }

    # annual cost diff
    cost_year <- cost_diff_lookup[[as.character(year)]]

    if (is.null(cost_year)) {
      cost_diff <- rep(0, n_offtakers)
    } else {
      cost_vec <- cost_year$cost_diff
      names(cost_vec) <- cost_year$sector
      cost_diff <- unname(cost_vec[sector])
      cost_diff[is.na(cost_diff)] <- 0
    }

    original_cost_diff <- cost_diff

    # intervention effect
    if (length(target_offtakers)) {
      cost_diff[target_offtakers] <- pmax(0, cost_diff[target_offtakers])
    }

    cost_diff_mat[, tt] <- cost_diff
    original_cost_diff_mat[, tt] <- original_cost_diff

    # raw adoption probability
    p_raw <- adopt_prob(
      beta0_vec,
      beta1_vec, spatial_influence_detrended,
      beta2_vec, cost_diff,
      beta3_vec, distance_waterway,
      beta4_vec, distance_pipeline,
      beta5_vec
    )
    p_raw[is.na(p_raw)] <- 0

    # residual adoption space
    sector_sum <- rowsum(previous_adoption, group = sector_factor, reorder = FALSE)
    sector_mean <- as.numeric(sector_sum) / sector_counts
    sector_mean_vec <- sector_mean[sector_factor]

    residual_share <- pmax(
      0,
      (beta6_vec - sector_mean_vec) / pmax(1 - sector_mean_vec, 1e-6)
    )

    residual_p <- p_raw * residual_share
    residual_p[is.na(residual_p)] <- 0

    # adoption update
    adoption <- previous_adoption

    if (any(continuous_flag)) {
      idx_c <- which(continuous_flag)
      adoption[idx_c] <- 1 - (1 - adoption[idx_c]) * (1 - residual_p[idx_c])
    }

    for (s in discrete_sectors) {
      idx_s <- sector_index[[s]]
      adoption[idx_s] <- pmax(
        adoption[idx_s],
        rbinom(length(idx_s), 1, residual_p[idx_s])
      )
    }

    adoption[beta6_vec == 0] <- 0
    adoption_mat[, tt] <- adoption

    # policy cost
    policy_cost_mat[, tt] <- ifelse(
      original_cost_diff < 0 & cost_diff == 0,
      hydrogen_2050 * (-original_cost_diff) * adoption * 33000 / 1e9,
      0
    )

    previous_adoption <- adoption
  }

  # long outputs
  year_rep <- rep(years, each = n_offtakers)
  plant_rep <- rep(plant_id, times = n_years)
  sector_rep <- rep(sector, times = n_years)
  h2050_rep <- rep(hydrogen_2050, times = n_years)

  adoption_plant_df <- tibble(
    year = year_rep,
    plant_id = plant_rep,
    sector = sector_rep,
    adoption = as.vector(adoption_mat),
    cost_diff = as.vector(cost_diff_mat),
    original_cost_diff = as.vector(original_cost_diff_mat),
    hydrogen_2050 = h2050_rep
  )

  policy_cost_df <- tibble(
    year = year_rep,
    plant_id = plant_rep,
    policy_cost = as.vector(policy_cost_mat)
  )

  cost_diff_df <- tibble(
    year = year_rep,
    plant_id = plant_rep,
    cost_diff = as.vector(cost_diff_mat)
  )

  # return
  list(
    adoption_plant = adoption_plant_df,
    policy_cost = policy_cost_df,
    cost_diff = cost_diff_df,
    influence_plant = if (length(target_offtakers)) bind_rows(influence_plant_list) else NULL,
    influence_summary = if (length(target_offtakers)) bind_rows(influence_summary_list) else NULL,
    treated_offtakers = if (length(target_offtakers)) {
      tibble(
        plant_id = plant_id,
        treatment = case_when(
          treated_flag_vec & intervention_type == "high" ~ "Treated High",
          treated_flag_vec & intervention_type == "low" ~ "Treated Low",
          treated_flag_vec & intervention_type == "random" ~ "Treated Random",
          TRUE ~ "Untreated"
        )
      )
    } else {
      NULL
    },
    sector_quantile_summary = sector_quantile_summary
  )
}

# %%
## runs and aggregation
#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

results_all <- list()
results_all_dist <- list()

for (i in seq_len(n_simulations)) {
  seed_i <- seeds[i]

  for (cent_name in names(centrality_types)) {

    score <- centrality_types[[cent_name]]

    for (intervention in intervention_types) {

      key <- paste(cent_name, intervention, sep = "_")

      run_result <- run_simulation(
        intervention_type  = intervention,
        seed               = seed_i,
        contribution_score = score
      )

      this_summary <- summarize_run(run_result)

      # first run initializes storage
      if (i == 1) {

        results_all[[key]]      <- run_result
        results_all_dist[[key]] <- list(this_summary)

      } else {

        # keep all annual summaries by run
        results_all_dist[[key]][[i]] <- this_summary

        # running average for adoption outputs
        base <- results_all[[key]]$adoption_plant
        new  <- run_result$adoption_plant

        num_cols <- setdiff(names(base), c("year", "plant_id", "sector", "hydrogen_2050"))
        base[num_cols] <- (base[num_cols] * (i - 1) + new[num_cols]) / i
        results_all[[key]]$adoption_plant <- base

        # running average for policy cost
        base <- results_all[[key]]$policy_cost
        new  <- run_result$policy_cost

        base$policy_cost <- (base$policy_cost * (i - 1) + new$policy_cost) / i
        results_all[[key]]$policy_cost <- base

        # running average for cost differences
        base <- results_all[[key]]$cost_diff
        new  <- run_result$cost_diff

        base$cost_diff <- (base$cost_diff * (i - 1) + new$cost_diff) / i
        results_all[[key]]$cost_diff <- base

        # running average for plant-level influence diagnostics
        base_infl <- results_all[[key]]$influence_plant
        new_infl  <- run_result$influence_plant

        if (!is.null(base_infl) && !is.null(new_infl) &&
            nrow(base_infl) > 0 && nrow(new_infl) > 0) {
          base_infl$spatial_influence <- (base_infl$spatial_influence * (i - 1) + new_infl$spatial_influence) / i
          results_all[[key]]$influence_plant <- base_infl
        }

        # running average for aggregate influence diagnostics
        base_sum <- results_all[[key]]$influence_summary
        new_sum  <- run_result$influence_summary

        if (!is.null(base_sum) && !is.null(new_sum) &&
            nrow(base_sum) > 0 && nrow(new_sum) > 0) {
          num_cols <- setdiff(names(base_sum), "year")
          base_sum[num_cols] <- (base_sum[num_cols] * (i - 1) + new_sum[num_cols]) / i
          results_all[[key]]$influence_summary <- base_sum
        }
      }

      message(sprintf("[%s] finished run %d/%d for %s",
                      Sys.time(), i, n_simulations, key))

      rm(run_result)
      if (i %% 5 == 0) gc()
    }
  }
}

# save per-run summaries
saveRDS(results_all_dist, "results_all_dist_split.rds")
# Out:
# [2026-03-24 19:39:37.189885] finished run 1/100 for betweenness_baseline
#
# [2026-03-24 19:39:38.409783] finished run 1/100 for betweenness_high
#
# [2026-03-24 19:39:39.583099] finished run 1/100 for betweenness_low
#
# [2026-03-24 19:39:40.683252] finished run 1/100 for betweenness_random
#
# [2026-03-24 19:39:41.430415] finished run 1/100 for degree_baseline
#
# [2026-03-24 19:39:42.292402] finished run 1/100 for degree_high
#
# [2026-03-24 19:39:43.088058] finished run 1/100 for degree_low
#
# [2026-03-24 19:39:44.054412] finished run 1/100 for degree_random
#
# [2026-03-24 19:39:44.881554] finished run 2/100 for betweenness_baseline
#
# [2026-03-24 19:39:45.702096] finished run 2/100 for betweenness_high
#
# [2026-03-24 19:39:46.700609] finished run 2/100 for betweenness_low
#
# [2026-03-24 19:39:47.471364] finished run 2/100 for betweenness_random
#
# [2026-03-24 19:39:48.002543] finished run 2/100 for degree_baseline
#
# [2026-03-24 19:39:48.869672] finished run 2/100 for degree_high
#
# [2026-03-24 19:39:49.584642] finished run 2/100 for degree_low
#
# [2026-03-24 19:39:50.295182] finished run 2/100 for degree_random
#
# [2026-03-24 19:39:51.140677] finished run 3/100 for betweenness_baseline
#
# [2026-03-24 19:39:51.836142] finished run 3/100 for betweenness_high
#
# [2026-03-24 19:39:52.532901] finished run 3/100 for betweenness_low
#
# [2026-03-24 19:39:53.490991] finished run 3/100 for betweenness_random
#
# [2026-03-24 19:39:53.988213] finished run 3/100 for degree_baseline
#
# [2026-03-24 19:39:54.69004] finished run 3/100 for degree_high
#
# [2026-03-24 19:39:55.563263] finished run 3/100 for degree_low
#
# [2026-03-24 19:39:56.213706] finished run 3/100 for degree_random
#
# [2026-03-24 19:39:56.871224] finished run 4/100 for betweenness_baseline
#
# [2026-03-24 19:39:57.658111] finished run 4/100 for betweenness_high
#
# [2026-03-24 19:39:58.351599] finished run 4/100 for betweenness_low
#
# [2026-03-24 19:39:59.141407] finished run 4/100 for betweenness_random
#
# [2026-03-24 19:39:59.639727] finished run 4/100 for degree_baseline
#
# [2026-03-24 19:40:00.364549] finished run 4/100 for degree_high
#
# [2026-03-24 19:40:01.185225] finished run 4/100 for degree_low
#
# [2026-03-24 19:40:01.831457] finished run 4/100 for degree_random
#
# [2026-03-24 19:40:02.323146] finished run 5/100 for betweenness_baseline
#
# [2026-03-24 19:40:03.139828] finished run 5/100 for betweenness_high
#
# [2026-03-24 19:40:03.960523] finished run 5/100 for betweenness_low
#
# [2026-03-24 19:40:04.734452] finished run 5/100 for betweenness_random
#
# [2026-03-24 19:40:05.35256] finished run 5/100 for degree_baseline
#
# [2026-03-24 19:40:06.166276] finished run 5/100 for degree_high
#
# [2026-03-24 19:40:06.987966] finished run 5/100 for degree_low
#
# [2026-03-24 19:40:07.76152] finished run 5/100 for degree_random
#
# [2026-03-24 19:40:08.372794] finished run 6/100 for betweenness_baseline
#
# [2026-03-24 19:40:09.197753] finished run 6/100 for betweenness_high
#
# [2026-03-24 19:40:09.881003] finished run 6/100 for betweenness_low
#
# [2026-03-24 19:40:10.528045] finished run 6/100 for betweenness_random
#
# [2026-03-24 19:40:11.141566] finished run 6/100 for degree_baseline
#
# [2026-03-24 19:40:11.823969] finished run 6/100 for degree_high
#
# [2026-03-24 19:40:12.51814] finished run 6/100 for degree_low
#
# [2026-03-24 19:40:13.299912] finished run 6/100 for degree_random
#
# [2026-03-24 19:40:13.773739] finished run 7/100 for betweenness_baseline
#
# [2026-03-24 19:40:14.593079] finished run 7/100 for betweenness_high
#
# [2026-03-24 19:40:15.286095] finished run 7/100 for betweenness_low
#
# [2026-03-24 19:40:15.928332] finished run 7/100 for betweenness_random
#
# [2026-03-24 19:40:16.436341] finished run 7/100 for degree_baseline
#
# [2026-03-24 19:40:17.272681] finished run 7/100 for degree_high
#
# [2026-03-24 19:40:17.950391] finished run 7/100 for degree_low
#
# [2026-03-24 19:40:18.605381] finished run 7/100 for degree_random
#
# [2026-03-24 19:40:19.222284] finished run 8/100 for betweenness_baseline
#
# [2026-03-24 19:40:19.910003] finished run 8/100 for betweenness_high
#
# [2026-03-24 19:40:20.600901] finished run 8/100 for betweenness_low
#
# [2026-03-24 19:40:21.384691] finished run 8/100 for betweenness_random
#
# [2026-03-24 19:40:21.865456] finished run 8/100 for degree_baseline
#
# [2026-03-24 19:40:22.557201] finished run 8/100 for degree_high
#
# [2026-03-24 19:40:23.375775] finished run 8/100 for degree_low
#
# [2026-03-24 19:40:24.157142] finished run 8/100 for degree_random
#
# [2026-03-24 19:40:24.646792] finished run 9/100 for betweenness_baseline
#
# [2026-03-24 19:40:25.353057] finished run 9/100 for betweenness_high
#
# [2026-03-24 19:40:26.174487] finished run 9/100 for betweenness_low
#
# [2026-03-24 19:40:26.823192] finished run 9/100 for betweenness_random
#
# [2026-03-24 19:40:27.29918] finished run 9/100 for degree_baseline
#
# [2026-03-24 19:40:28.119407] finished run 9/100 for degree_high
#
# [2026-03-24 19:40:28.80786] finished run 9/100 for degree_low
#
# [2026-03-24 19:40:29.587107] finished run 9/100 for degree_random
#
# [2026-03-24 19:40:30.065964] finished run 10/100 for betweenness_baseline
#
# [2026-03-24 19:40:30.88605] finished run 10/100 for betweenness_high
#
# [2026-03-24 19:40:31.705544] finished run 10/100 for betweenness_low
#
# [2026-03-24 19:40:32.481236] finished run 10/100 for betweenness_random
#
# [2026-03-24 19:40:33.093627] finished run 10/100 for degree_baseline
#
# [2026-03-24 19:40:33.921791] finished run 10/100 for degree_high
#
# [2026-03-24 19:40:34.742227] finished run 10/100 for degree_low
#
# [2026-03-24 19:40:35.529391] finished run 10/100 for degree_random
#
# [2026-03-24 19:40:36.145694] finished run 11/100 for betweenness_baseline
#
# [2026-03-24 19:40:36.827881] finished run 11/100 for betweenness_high
#
# [2026-03-24 19:40:37.542068] finished run 11/100 for betweenness_low
#
# [2026-03-24 19:40:38.318331] finished run 11/100 for betweenness_random
#
# [2026-03-24 19:40:38.805832] finished run 11/100 for degree_baseline
#
# [2026-03-24 19:40:39.504249] finished run 11/100 for degree_high
#
# [2026-03-24 19:40:40.323893] finished run 11/100 for degree_low
#
# [2026-03-24 19:40:41.103561] finished run 11/100 for degree_random
#
# [2026-03-24 19:40:41.569842] finished run 12/100 for betweenness_baseline
#
# [2026-03-24 19:40:42.312149] finished run 12/100 for betweenness_high
#
# [2026-03-24 19:40:43.022066] finished run 12/100 for betweenness_low
#
# [2026-03-24 19:40:43.682277] finished run 12/100 for betweenness_random
#
# [2026-03-24 19:40:44.289434] finished run 12/100 for degree_baseline
#
# [2026-03-24 19:40:44.959345] finished run 12/100 for degree_high
#
# [2026-03-24 19:40:45.658926] finished run 12/100 for degree_low
#
# [2026-03-24 19:40:46.311386] finished run 12/100 for degree_random
#
# [2026-03-24 19:40:46.790559] finished run 13/100 for betweenness_baseline
#
# [2026-03-24 19:40:47.611714] finished run 13/100 for betweenness_high
#
# [2026-03-24 19:40:48.292989] finished run 13/100 for betweenness_low
#
# [2026-03-24 19:40:48.930172] finished run 13/100 for betweenness_random
#
# [2026-03-24 19:40:49.539847] finished run 13/100 for degree_baseline
#
# [2026-03-24 19:40:50.21582] finished run 13/100 for degree_high
#
# [2026-03-24 19:40:50.895545] finished run 13/100 for degree_low
#
# [2026-03-24 19:40:51.537948] finished run 13/100 for degree_random
#
# [2026-03-24 19:40:52.011384] finished run 14/100 for betweenness_baseline
#
# [2026-03-24 19:40:52.695869] finished run 14/100 for betweenness_high
#
# [2026-03-24 19:40:53.512501] finished run 14/100 for betweenness_low
#
# [2026-03-24 19:40:54.148441] finished run 14/100 for betweenness_random
#
# [2026-03-24 19:40:54.633251] finished run 14/100 for degree_baseline
#
# [2026-03-24 19:40:55.312834] finished run 14/100 for degree_high
#
# [2026-03-24 19:40:56.124735] finished run 14/100 for degree_low
#
# [2026-03-24 19:40:56.763182] finished run 14/100 for degree_random
#
# [2026-03-24 19:40:57.25445] finished run 15/100 for betweenness_baseline
#
# [2026-03-24 19:40:58.060256] finished run 15/100 for betweenness_high
#
# [2026-03-24 19:40:58.86623] finished run 15/100 for betweenness_low
#
# [2026-03-24 19:40:59.638393] finished run 15/100 for betweenness_random
#
# [2026-03-24 19:41:00.238023] finished run 15/100 for degree_baseline
#
# [2026-03-24 19:41:01.047647] finished run 15/100 for degree_high
#
# [2026-03-24 19:41:01.854386] finished run 15/100 for degree_low
#
# [2026-03-24 19:41:02.649352] finished run 15/100 for degree_random
#
# [2026-03-24 19:41:03.450105] finished run 16/100 for betweenness_baseline
#
# [2026-03-24 19:41:04.238609] finished run 16/100 for betweenness_high
#
# [2026-03-24 19:41:04.919962] finished run 16/100 for betweenness_low
#
# [2026-03-24 19:41:05.716762] finished run 16/100 for betweenness_random
#
# [2026-03-24 19:41:06.183429] finished run 16/100 for degree_baseline
#
# [2026-03-24 19:41:06.865631] finished run 16/100 for degree_high
#
# [2026-03-24 19:41:07.547865] finished run 16/100 for degree_low
#
# [2026-03-24 19:41:08.188887] finished run 16/100 for degree_random
#
# [2026-03-24 19:41:08.7044] finished run 17/100 for betweenness_baseline
#
# [2026-03-24 19:41:09.420844] finished run 17/100 for betweenness_high
#
# [2026-03-24 19:41:10.249694] finished run 17/100 for betweenness_low
#
# [2026-03-24 19:41:10.88984] finished run 17/100 for betweenness_random
#
# [2026-03-24 19:41:11.366802] finished run 17/100 for degree_baseline
#
# [2026-03-24 19:41:12.048785] finished run 17/100 for degree_high
#
# [2026-03-24 19:41:12.736838] finished run 17/100 for degree_low
#
# [2026-03-24 19:41:13.51481] finished run 17/100 for degree_random
#
# [2026-03-24 19:41:13.986425] finished run 18/100 for betweenness_baseline
#
# [2026-03-24 19:41:14.667807] finished run 18/100 for betweenness_high
#
# [2026-03-24 19:41:15.358609] finished run 18/100 for betweenness_low
#
# [2026-03-24 19:41:16.000719] finished run 18/100 for betweenness_random
#
# [2026-03-24 19:41:16.625489] finished run 18/100 for degree_baseline
#
# [2026-03-24 19:41:17.303778] finished run 18/100 for degree_high
#
# [2026-03-24 19:41:17.988205] finished run 18/100 for degree_low
#
# [2026-03-24 19:41:18.667254] finished run 18/100 for degree_random
#
# [2026-03-24 19:41:19.17819] finished run 19/100 for betweenness_baseline
#
# [2026-03-24 19:41:20.027162] finished run 19/100 for betweenness_high
#
# [2026-03-24 19:41:20.737706] finished run 19/100 for betweenness_low
#
# [2026-03-24 19:41:21.390364] finished run 19/100 for betweenness_random
#
# [2026-03-24 19:41:21.871433] finished run 19/100 for degree_baseline
#
# [2026-03-24 19:41:22.583497] finished run 19/100 for degree_high
#
# [2026-03-24 19:41:23.414587] finished run 19/100 for degree_low
#
# [2026-03-24 19:41:24.107501] finished run 19/100 for degree_random
#
# [2026-03-24 19:41:24.587813] finished run 20/100 for betweenness_baseline
#
# [2026-03-24 19:41:25.425695] finished run 20/100 for betweenness_high
#
# [2026-03-24 19:41:26.253305] finished run 20/100 for betweenness_low
#
# [2026-03-24 19:41:27.031348] finished run 20/100 for betweenness_random
#
# [2026-03-24 19:41:27.643735] finished run 20/100 for degree_baseline
#
# [2026-03-24 19:41:28.462605] finished run 20/100 for degree_high
#
# [2026-03-24 19:41:29.286173] finished run 20/100 for degree_low
#
# [2026-03-24 19:41:30.069259] finished run 20/100 for degree_random
#
# [2026-03-24 19:41:30.67684] finished run 21/100 for betweenness_baseline
#
# [2026-03-24 19:41:31.35271] finished run 21/100 for betweenness_high
#
# [2026-03-24 19:41:32.033413] finished run 21/100 for betweenness_low
#
# [2026-03-24 19:41:32.724749] finished run 21/100 for betweenness_random
#
# [2026-03-24 19:41:33.196243] finished run 21/100 for degree_baseline
#
# [2026-03-24 19:41:33.876345] finished run 21/100 for degree_high
#
# [2026-03-24 19:41:34.564037] finished run 21/100 for degree_low
#
# [2026-03-24 19:41:35.362164] finished run 21/100 for degree_random
#
# [2026-03-24 19:41:35.834339] finished run 22/100 for betweenness_baseline
#
# [2026-03-24 19:41:36.516629] finished run 22/100 for betweenness_high
#
# [2026-03-24 19:41:37.198589] finished run 22/100 for betweenness_low
#
# [2026-03-24 19:41:37.985207] finished run 22/100 for betweenness_random
#
# [2026-03-24 19:41:38.457134] finished run 22/100 for degree_baseline
#
# [2026-03-24 19:41:39.140854] finished run 22/100 for degree_high
#
# [2026-03-24 19:41:39.821797] finished run 22/100 for degree_low
#
# [2026-03-24 19:41:40.473276] finished run 22/100 for degree_random
#
# [2026-03-24 19:41:41.09766] finished run 23/100 for betweenness_baseline
#
# [2026-03-24 19:41:41.775073] finished run 23/100 for betweenness_high
#
# [2026-03-24 19:41:42.461681] finished run 23/100 for betweenness_low
#
# [2026-03-24 19:41:43.117302] finished run 23/100 for betweenness_random
#
# [2026-03-24 19:41:43.593509] finished run 23/100 for degree_baseline
#
# [2026-03-24 19:41:44.428268] finished run 23/100 for degree_high
#
# [2026-03-24 19:41:45.147102] finished run 23/100 for degree_low
#
# [2026-03-24 19:41:45.795982] finished run 23/100 for degree_random
#
# [2026-03-24 19:41:46.276957] finished run 24/100 for betweenness_baseline
#
# [2026-03-24 19:41:46.967426] finished run 24/100 for betweenness_high
#
# [2026-03-24 19:41:47.680333] finished run 24/100 for betweenness_low
#
# [2026-03-24 19:41:48.514603] finished run 24/100 for betweenness_random
#
# [2026-03-24 19:41:48.991125] finished run 24/100 for degree_baseline
#
# [2026-03-24 19:41:49.683912] finished run 24/100 for degree_high
#
# [2026-03-24 19:41:50.396947] finished run 24/100 for degree_low
#
# [2026-03-24 19:41:51.042758] finished run 24/100 for degree_random
#
# [2026-03-24 19:41:51.670544] finished run 25/100 for betweenness_baseline
#
# [2026-03-24 19:41:52.494126] finished run 25/100 for betweenness_high
#
# [2026-03-24 19:41:53.347344] finished run 25/100 for betweenness_low
#
# [2026-03-24 19:41:54.159059] finished run 25/100 for betweenness_random
#
# [2026-03-24 19:41:54.771419] finished run 25/100 for degree_baseline
#
# [2026-03-24 19:41:55.592128] finished run 25/100 for degree_high
#
# [2026-03-24 19:41:56.412241] finished run 25/100 for degree_low
#
# [2026-03-24 19:41:57.333946] finished run 25/100 for degree_random
#
# [2026-03-24 19:41:57.951668] finished run 26/100 for betweenness_baseline
#
# [2026-03-24 19:41:58.658274] finished run 26/100 for betweenness_high
#
# [2026-03-24 19:41:59.344541] finished run 26/100 for betweenness_low
#
# [2026-03-24 19:42:00.035944] finished run 26/100 for betweenness_random
#
# [2026-03-24 19:42:00.510537] finished run 26/100 for degree_baseline
#
# [2026-03-24 19:42:01.206026] finished run 26/100 for degree_high
#
# [2026-03-24 19:42:01.917567] finished run 26/100 for degree_low
#
# [2026-03-24 19:42:02.742033] finished run 26/100 for degree_random
#
# [2026-03-24 19:42:03.226125] finished run 27/100 for betweenness_baseline
#
# [2026-03-24 19:42:03.907889] finished run 27/100 for betweenness_high
#
# [2026-03-24 19:42:04.602612] finished run 27/100 for betweenness_low
#
# [2026-03-24 19:42:05.272929] finished run 27/100 for betweenness_random
#
# [2026-03-24 19:42:05.911696] finished run 27/100 for degree_baseline
#
# [2026-03-24 19:42:06.595541] finished run 27/100 for degree_high
#
# [2026-03-24 19:42:07.27823] finished run 27/100 for degree_low
#
# [2026-03-24 19:42:08.056862] finished run 27/100 for degree_random
#
# [2026-03-24 19:42:08.540609] finished run 28/100 for betweenness_baseline
#
# [2026-03-24 19:42:09.221436] finished run 28/100 for betweenness_high
#
# [2026-03-24 19:42:09.909055] finished run 28/100 for betweenness_low
#
# [2026-03-24 19:42:10.555267] finished run 28/100 for betweenness_random
#
# [2026-03-24 19:42:11.028645] finished run 28/100 for degree_baseline
#
# [2026-03-24 19:42:11.768138] finished run 28/100 for degree_high
#
# [2026-03-24 19:42:12.605359] finished run 28/100 for degree_low
#
# [2026-03-24 19:42:13.245223] finished run 28/100 for degree_random
#
# [2026-03-24 19:42:13.718234] finished run 29/100 for betweenness_baseline
#
# [2026-03-24 19:42:14.409486] finished run 29/100 for betweenness_high
#
# [2026-03-24 19:42:15.095042] finished run 29/100 for betweenness_low
#
# [2026-03-24 19:42:15.878165] finished run 29/100 for betweenness_random
#
# [2026-03-24 19:42:16.351801] finished run 29/100 for degree_baseline
#
# [2026-03-24 19:42:17.034451] finished run 29/100 for degree_high
#
# [2026-03-24 19:42:17.716168] finished run 29/100 for degree_low
#
# [2026-03-24 19:42:18.366099] finished run 29/100 for degree_random
#
# [2026-03-24 19:42:18.846925] finished run 30/100 for betweenness_baseline
#
# [2026-03-24 19:42:19.663667] finished run 30/100 for betweenness_high
#
# [2026-03-24 19:42:20.487508] finished run 30/100 for betweenness_low
#
# [2026-03-24 19:42:21.268437] finished run 30/100 for betweenness_random
#
# [2026-03-24 19:42:21.877798] finished run 30/100 for degree_baseline
#
# [2026-03-24 19:42:22.698233] finished run 30/100 for degree_high
#
# [2026-03-24 19:42:23.513936] finished run 30/100 for degree_low
#
# [2026-03-24 19:42:24.296226] finished run 30/100 for degree_random
#
# [2026-03-24 19:42:24.906043] finished run 31/100 for betweenness_baseline
#
# [2026-03-24 19:42:25.585747] finished run 31/100 for betweenness_high
#
# [2026-03-24 19:42:26.266976] finished run 31/100 for betweenness_low
#
# [2026-03-24 19:42:26.964131] finished run 31/100 for betweenness_random
#
# [2026-03-24 19:42:27.436723] finished run 31/100 for degree_baseline
#
# [2026-03-24 19:42:28.125761] finished run 31/100 for degree_high
#
# [2026-03-24 19:42:28.950141] finished run 31/100 for degree_low
#
# [2026-03-24 19:42:29.589796] finished run 31/100 for degree_random
#
# [2026-03-24 19:42:30.072174] finished run 32/100 for betweenness_baseline
#
# [2026-03-24 19:42:30.762578] finished run 32/100 for betweenness_high
#
# [2026-03-24 19:42:31.44466] finished run 32/100 for betweenness_low
#
# [2026-03-24 19:42:32.097136] finished run 32/100 for betweenness_random
#
# [2026-03-24 19:42:32.575165] finished run 32/100 for degree_baseline
#
# [2026-03-24 19:42:33.403856] finished run 32/100 for degree_high
#
# [2026-03-24 19:42:34.088442] finished run 32/100 for degree_low
#
# [2026-03-24 19:42:34.72891] finished run 32/100 for degree_random
#
# [2026-03-24 19:42:35.210464] finished run 33/100 for betweenness_baseline
#
# [2026-03-24 19:42:35.902951] finished run 33/100 for betweenness_high
#
# [2026-03-24 19:42:36.716556] finished run 33/100 for betweenness_low
#
# [2026-03-24 19:42:37.356658] finished run 33/100 for betweenness_random
#
# [2026-03-24 19:42:37.82777] finished run 33/100 for degree_baseline
#
# [2026-03-24 19:42:38.514902] finished run 33/100 for degree_high
#
# [2026-03-24 19:42:39.202613] finished run 33/100 for degree_low
#
# [2026-03-24 19:42:39.850623] finished run 33/100 for degree_random
#
# [2026-03-24 19:42:40.365437] finished run 34/100 for betweenness_baseline
#
# [2026-03-24 19:42:41.054749] finished run 34/100 for betweenness_high
#
# [2026-03-24 19:42:41.873592] finished run 34/100 for betweenness_low
#
# [2026-03-24 19:42:42.517112] finished run 34/100 for betweenness_random
#
# [2026-03-24 19:42:42.988714] finished run 34/100 for degree_baseline
#
# [2026-03-24 19:42:43.674415] finished run 34/100 for degree_high
#
# [2026-03-24 19:42:44.358032] finished run 34/100 for degree_low
#
# [2026-03-24 19:42:45.139656] finished run 34/100 for degree_random
#
# [2026-03-24 19:42:45.616248] finished run 35/100 for betweenness_baseline
#
# [2026-03-24 19:42:46.441556] finished run 35/100 for betweenness_high
#
# [2026-03-24 19:42:47.263321] finished run 35/100 for betweenness_low
#
# [2026-03-24 19:42:48.044078] finished run 35/100 for betweenness_random
#
# [2026-03-24 19:42:48.651966] finished run 35/100 for degree_baseline
#
# [2026-03-24 19:42:49.465221] finished run 35/100 for degree_high
#
# [2026-03-24 19:42:50.29035] finished run 35/100 for degree_low
#
# [2026-03-24 19:42:51.071307] finished run 35/100 for degree_random
#
# [2026-03-24 19:42:51.679459] finished run 36/100 for betweenness_baseline
#
# [2026-03-24 19:42:52.353325] finished run 36/100 for betweenness_high
#
# [2026-03-24 19:42:53.035356] finished run 36/100 for betweenness_low
#
# [2026-03-24 19:42:53.719405] finished run 36/100 for betweenness_random
#
# [2026-03-24 19:42:54.193273] finished run 36/100 for degree_baseline
#
# [2026-03-24 19:42:54.881635] finished run 36/100 for degree_high
#
# [2026-03-24 19:42:55.575418] finished run 36/100 for degree_low
#
# [2026-03-24 19:42:56.367571] finished run 36/100 for degree_random
#
# [2026-03-24 19:42:56.841229] finished run 37/100 for betweenness_baseline
#
# [2026-03-24 19:42:57.525398] finished run 37/100 for betweenness_high
#
# [2026-03-24 19:42:58.213423] finished run 37/100 for betweenness_low
#
# [2026-03-24 19:42:58.997429] finished run 37/100 for betweenness_random
#
# [2026-03-24 19:42:59.470831] finished run 37/100 for degree_baseline
#
# [2026-03-24 19:43:00.155753] finished run 37/100 for degree_high
#
# [2026-03-24 19:43:00.981861] finished run 37/100 for degree_low
#
# [2026-03-24 19:43:01.629967] finished run 37/100 for degree_random
#
# [2026-03-24 19:43:02.10352] finished run 38/100 for betweenness_baseline
#
# [2026-03-24 19:43:02.795612] finished run 38/100 for betweenness_high
#
# [2026-03-24 19:43:03.51208] finished run 38/100 for betweenness_low
#
# [2026-03-24 19:43:04.288876] finished run 38/100 for betweenness_random
#
# [2026-03-24 19:43:04.763127] finished run 38/100 for degree_baseline
#
# [2026-03-24 19:43:05.448672] finished run 38/100 for degree_high
#
# [2026-03-24 19:43:06.132068] finished run 38/100 for degree_low
#
# [2026-03-24 19:43:06.776082] finished run 38/100 for degree_random
#
# [2026-03-24 19:43:07.257381] finished run 39/100 for betweenness_baseline
#
# [2026-03-24 19:43:08.077153] finished run 39/100 for betweenness_high
#
# [2026-03-24 19:43:08.756326] finished run 39/100 for betweenness_low
#
# [2026-03-24 19:43:09.398641] finished run 39/100 for betweenness_random
#
# [2026-03-24 19:43:09.883399] finished run 39/100 for degree_baseline
#
# [2026-03-24 19:43:10.568373] finished run 39/100 for degree_high
#
# [2026-03-24 19:43:11.261253] finished run 39/100 for degree_low
#
# [2026-03-24 19:43:12.055505] finished run 39/100 for degree_random
#
# [2026-03-24 19:43:12.52888] finished run 40/100 for betweenness_baseline
#
# [2026-03-24 19:43:13.342964] finished run 40/100 for betweenness_high
#
# [2026-03-24 19:43:14.163006] finished run 40/100 for betweenness_low
#
# [2026-03-24 19:43:14.944364] finished run 40/100 for betweenness_random
#
# [2026-03-24 19:43:15.554835] finished run 40/100 for degree_baseline
#
# [2026-03-24 19:43:16.368438] finished run 40/100 for degree_high
#
# [2026-03-24 19:43:17.186054] finished run 40/100 for degree_low
#
# [2026-03-24 19:43:17.964183] finished run 40/100 for degree_random
#
# [2026-03-24 19:43:18.573442] finished run 41/100 for betweenness_baseline
#
# [2026-03-24 19:43:19.256447] finished run 41/100 for betweenness_high
#
# [2026-03-24 19:43:19.939229] finished run 41/100 for betweenness_low
#
# [2026-03-24 19:43:20.646736] finished run 41/100 for betweenness_random
#
# [2026-03-24 19:43:21.119082] finished run 41/100 for degree_baseline
#
# [2026-03-24 19:43:21.952498] finished run 41/100 for degree_high
#
# [2026-03-24 19:43:22.629511] finished run 41/100 for degree_low
#
# [2026-03-24 19:43:23.274005] finished run 41/100 for degree_random
#
# [2026-03-24 19:43:23.753597] finished run 42/100 for betweenness_baseline
#
# [2026-03-24 19:43:24.438323] finished run 42/100 for betweenness_high
#
# [2026-03-24 19:43:25.115263] finished run 42/100 for betweenness_low
#
# [2026-03-24 19:43:25.894955] finished run 42/100 for betweenness_random
#
# [2026-03-24 19:43:26.362695] finished run 42/100 for degree_baseline
#
# [2026-03-24 19:43:27.040624] finished run 42/100 for degree_high
#
# [2026-03-24 19:43:27.723646] finished run 42/100 for degree_low
#
# [2026-03-24 19:43:28.359318] finished run 42/100 for degree_random
#
# [2026-03-24 19:43:28.965737] finished run 43/100 for betweenness_baseline
#
# [2026-03-24 19:43:29.641589] finished run 43/100 for betweenness_high
#
# [2026-03-24 19:43:30.316764] finished run 43/100 for betweenness_low
#
# [2026-03-24 19:43:30.961552] finished run 43/100 for betweenness_random
#
# [2026-03-24 19:43:31.429244] finished run 43/100 for degree_baseline
#
# [2026-03-24 19:43:32.107527] finished run 43/100 for degree_high
#
# [2026-03-24 19:43:32.805279] finished run 43/100 for degree_low
#
# [2026-03-24 19:43:33.57221] finished run 43/100 for degree_random
#
# [2026-03-24 19:43:34.043619] finished run 44/100 for betweenness_baseline
#
# [2026-03-24 19:43:34.722265] finished run 44/100 for betweenness_high
#
# [2026-03-24 19:43:35.40603] finished run 44/100 for betweenness_low
#
# [2026-03-24 19:43:36.039288] finished run 44/100 for betweenness_random
#
# [2026-03-24 19:43:36.648424] finished run 44/100 for degree_baseline
#
# [2026-03-24 19:43:37.319989] finished run 44/100 for degree_high
#
# [2026-03-24 19:43:37.997802] finished run 44/100 for degree_low
#
# [2026-03-24 19:43:38.635092] finished run 44/100 for degree_random
#
# [2026-03-24 19:43:39.245449] finished run 45/100 for betweenness_baseline
#
# [2026-03-24 19:43:40.053951] finished run 45/100 for betweenness_high
#
# [2026-03-24 19:43:40.866777] finished run 45/100 for betweenness_low
#
# [2026-03-24 19:43:41.637748] finished run 45/100 for betweenness_random
#
# [2026-03-24 19:43:42.241003] finished run 45/100 for degree_baseline
#
# [2026-03-24 19:43:43.046729] finished run 45/100 for degree_high
#
# [2026-03-24 19:43:43.860265] finished run 45/100 for degree_low
#
# [2026-03-24 19:43:44.62954] finished run 45/100 for degree_random
#
# [2026-03-24 19:43:45.240613] finished run 46/100 for betweenness_baseline
#
# [2026-03-24 19:43:45.912617] finished run 46/100 for betweenness_high
#
# [2026-03-24 19:43:46.590063] finished run 46/100 for betweenness_low
#
# [2026-03-24 19:43:47.229028] finished run 46/100 for betweenness_random
#
# [2026-03-24 19:43:47.707112] finished run 46/100 for degree_baseline
#
# [2026-03-24 19:43:48.441505] finished run 46/100 for degree_high
#
# [2026-03-24 19:43:49.2682] finished run 46/100 for degree_low
#
# [2026-03-24 19:43:49.900931] finished run 46/100 for degree_random
#
# [2026-03-24 19:43:50.380833] finished run 47/100 for betweenness_baseline
#
# [2026-03-24 19:43:51.05828] finished run 47/100 for betweenness_high
#
# [2026-03-24 19:43:51.874022] finished run 47/100 for betweenness_low
#
# [2026-03-24 19:43:52.507528] finished run 47/100 for betweenness_random
#
# [2026-03-24 19:43:52.979656] finished run 47/100 for degree_baseline
#
# [2026-03-24 19:43:53.656826] finished run 47/100 for degree_high
#
# [2026-03-24 19:43:54.341553] finished run 47/100 for degree_low
#
# [2026-03-24 19:43:55.133746] finished run 47/100 for degree_random
#
# [2026-03-24 19:43:55.601023] finished run 48/100 for betweenness_baseline
#
# [2026-03-24 19:43:56.287628] finished run 48/100 for betweenness_high
#
# [2026-03-24 19:43:56.96275] finished run 48/100 for betweenness_low
#
# [2026-03-24 19:43:57.604855] finished run 48/100 for betweenness_random
#
# [2026-03-24 19:43:58.205806] finished run 48/100 for degree_baseline
#
# [2026-03-24 19:43:58.879618] finished run 48/100 for degree_high
#
# [2026-03-24 19:43:59.558876] finished run 48/100 for degree_low
#
# [2026-03-24 19:44:00.203461] finished run 48/100 for degree_random
#
# [2026-03-24 19:44:00.675407] finished run 49/100 for betweenness_baseline
#
# [2026-03-24 19:44:01.354238] finished run 49/100 for betweenness_high
#
# [2026-03-24 19:44:02.047956] finished run 49/100 for betweenness_low
#
# [2026-03-24 19:44:02.814902] finished run 49/100 for betweenness_random
#
# [2026-03-24 19:44:03.283499] finished run 49/100 for degree_baseline
#
# [2026-03-24 19:44:03.960629] finished run 49/100 for degree_high
#
# [2026-03-24 19:44:04.638284] finished run 49/100 for degree_low
#
# [2026-03-24 19:44:05.279462] finished run 49/100 for degree_random
#
# [2026-03-24 19:44:05.889676] finished run 50/100 for betweenness_baseline
#
# [2026-03-24 19:44:06.694934] finished run 50/100 for betweenness_high
#
# [2026-03-24 19:44:07.50604] finished run 50/100 for betweenness_low
#
# [2026-03-24 19:44:08.285852] finished run 50/100 for betweenness_random
#
# [2026-03-24 19:44:08.888099] finished run 50/100 for degree_baseline
#
# [2026-03-24 19:44:09.699594] finished run 50/100 for degree_high
#
# [2026-03-24 19:44:10.514677] finished run 50/100 for degree_low
#
# [2026-03-24 19:44:11.288489] finished run 50/100 for degree_random
#
# [2026-03-24 19:44:11.88874] finished run 51/100 for betweenness_baseline
#
# [2026-03-24 19:44:12.555574] finished run 51/100 for betweenness_high
#
# [2026-03-24 19:44:13.229389] finished run 51/100 for betweenness_low
#
# [2026-03-24 19:44:13.907422] finished run 51/100 for betweenness_random
#
# [2026-03-24 19:44:14.375277] finished run 51/100 for degree_baseline
#
# [2026-03-24 19:44:15.06522] finished run 51/100 for degree_high
#
# [2026-03-24 19:44:15.739654] finished run 51/100 for degree_low
#
# [2026-03-24 19:44:16.521059] finished run 51/100 for degree_random
#
# [2026-03-24 19:44:16.988581] finished run 52/100 for betweenness_baseline
#
# [2026-03-24 19:44:17.664745] finished run 52/100 for betweenness_high
#
# [2026-03-24 19:44:18.346752] finished run 52/100 for betweenness_low
#
# [2026-03-24 19:44:19.120133] finished run 52/100 for betweenness_random
#
# [2026-03-24 19:44:19.58654] finished run 52/100 for degree_baseline
#
# [2026-03-24 19:44:20.264613] finished run 52/100 for degree_high
#
# [2026-03-24 19:44:20.950814] finished run 52/100 for degree_low
#
# [2026-03-24 19:44:21.593954] finished run 52/100 for degree_random
#
# [2026-03-24 19:44:22.196768] finished run 53/100 for betweenness_baseline
#
# [2026-03-24 19:44:22.877327] finished run 53/100 for betweenness_high
#
# [2026-03-24 19:44:23.553475] finished run 53/100 for betweenness_low
#
# [2026-03-24 19:44:24.202452] finished run 53/100 for betweenness_random
#
# [2026-03-24 19:44:24.670276] finished run 53/100 for degree_baseline
#
# [2026-03-24 19:44:25.352136] finished run 53/100 for degree_high
#
# [2026-03-24 19:44:26.199292] finished run 53/100 for degree_low
#
# [2026-03-24 19:44:26.832655] finished run 53/100 for degree_random
#
# [2026-03-24 19:44:27.436811] finished run 54/100 for betweenness_baseline
#
# [2026-03-24 19:44:28.107753] finished run 54/100 for betweenness_high
#
# [2026-03-24 19:44:28.782893] finished run 54/100 for betweenness_low
#
# [2026-03-24 19:44:29.426803] finished run 54/100 for betweenness_random
#
# [2026-03-24 19:44:29.901664] finished run 54/100 for degree_baseline
#
# [2026-03-24 19:44:30.586353] finished run 54/100 for degree_high
#
# [2026-03-24 19:44:31.408496] finished run 54/100 for degree_low
#
# [2026-03-24 19:44:32.04928] finished run 54/100 for degree_random
#
# [2026-03-24 19:44:32.523561] finished run 55/100 for betweenness_baseline
#
# [2026-03-24 19:44:33.337087] finished run 55/100 for betweenness_high
#
# [2026-03-24 19:44:34.147372] finished run 55/100 for betweenness_low
#
# [2026-03-24 19:44:34.919686] finished run 55/100 for betweenness_random
#
# [2026-03-24 19:44:35.525621] finished run 55/100 for degree_baseline
#
# [2026-03-24 19:44:36.332724] finished run 55/100 for degree_high
#
# [2026-03-24 19:44:37.145975] finished run 55/100 for degree_low
#
# [2026-03-24 19:44:37.917956] finished run 55/100 for degree_random
#
# [2026-03-24 19:44:38.521543] finished run 56/100 for betweenness_baseline
#
# [2026-03-24 19:44:39.194181] finished run 56/100 for betweenness_high
#
# [2026-03-24 19:44:39.871932] finished run 56/100 for betweenness_low
#
# [2026-03-24 19:44:40.570541] finished run 56/100 for betweenness_random
#
# [2026-03-24 19:44:41.038528] finished run 56/100 for degree_baseline
#
# [2026-03-24 19:44:41.871897] finished run 56/100 for degree_high
#
# [2026-03-24 19:44:42.544566] finished run 56/100 for degree_low
#
# [2026-03-24 19:44:43.183048] finished run 56/100 for degree_random
#
# [2026-03-24 19:44:43.655163] finished run 57/100 for betweenness_baseline
#
# [2026-03-24 19:44:44.337277] finished run 57/100 for betweenness_high
#
# [2026-03-24 19:44:45.016284] finished run 57/100 for betweenness_low
#
# [2026-03-24 19:44:45.797075] finished run 57/100 for betweenness_random
#
# [2026-03-24 19:44:46.265567] finished run 57/100 for degree_baseline
#
# [2026-03-24 19:44:46.943192] finished run 57/100 for degree_high
#
# [2026-03-24 19:44:47.625377] finished run 57/100 for degree_low
#
# [2026-03-24 19:44:48.406164] finished run 57/100 for degree_random
#
# [2026-03-24 19:44:48.873351] finished run 58/100 for betweenness_baseline
#
# [2026-03-24 19:44:49.551433] finished run 58/100 for betweenness_high
#
# [2026-03-24 19:44:50.235219] finished run 58/100 for betweenness_low
#
# [2026-03-24 19:44:50.874878] finished run 58/100 for betweenness_random
#
# [2026-03-24 19:44:51.494549] finished run 58/100 for degree_baseline
#
# [2026-03-24 19:44:52.165018] finished run 58/100 for degree_high
#
# [2026-03-24 19:44:52.852023] finished run 58/100 for degree_low
#
# [2026-03-24 19:44:53.507375] finished run 58/100 for degree_random
#
# [2026-03-24 19:44:53.979033] finished run 59/100 for betweenness_baseline
#
# [2026-03-24 19:44:54.798315] finished run 59/100 for betweenness_high
#
# [2026-03-24 19:44:55.4795] finished run 59/100 for betweenness_low
#
# [2026-03-24 19:44:56.115065] finished run 59/100 for betweenness_random
#
# [2026-03-24 19:44:56.586913] finished run 59/100 for degree_baseline
#
# [2026-03-24 19:44:57.263008] finished run 59/100 for degree_high
#
# [2026-03-24 19:44:57.949995] finished run 59/100 for degree_low
#
# [2026-03-24 19:44:58.724015] finished run 59/100 for degree_random
#
# [2026-03-24 19:44:59.192674] finished run 60/100 for betweenness_baseline
#
# [2026-03-24 19:45:00.001055] finished run 60/100 for betweenness_high
#
# [2026-03-24 19:45:00.814408] finished run 60/100 for betweenness_low
#
# [2026-03-24 19:45:01.58406] finished run 60/100 for betweenness_random
#
# [2026-03-24 19:45:02.18941] finished run 60/100 for degree_baseline
#
# [2026-03-24 19:45:02.995358] finished run 60/100 for degree_high
#
# [2026-03-24 19:45:03.807668] finished run 60/100 for degree_low
#
# [2026-03-24 19:45:04.577759] finished run 60/100 for degree_random
#
# [2026-03-24 19:45:05.183803] finished run 61/100 for betweenness_baseline
#
# [2026-03-24 19:45:05.856578] finished run 61/100 for betweenness_high
#
# [2026-03-24 19:45:06.534166] finished run 61/100 for betweenness_low
#
# [2026-03-24 19:45:07.17435] finished run 61/100 for betweenness_random
#
# [2026-03-24 19:45:07.645041] finished run 61/100 for degree_baseline
#
# [2026-03-24 19:45:08.368683] finished run 61/100 for degree_high
#
# [2026-03-24 19:45:09.187159] finished run 61/100 for degree_low
#
# [2026-03-24 19:45:09.821064] finished run 61/100 for degree_random
#
# [2026-03-24 19:45:10.291071] finished run 62/100 for betweenness_baseline
#
# [2026-03-24 19:45:10.970126] finished run 62/100 for betweenness_high
#
# [2026-03-24 19:45:11.656472] finished run 62/100 for betweenness_low
#
# [2026-03-24 19:45:12.426447] finished run 62/100 for betweenness_random
#
# [2026-03-24 19:45:12.893384] finished run 62/100 for degree_baseline
#
# [2026-03-24 19:45:13.571237] finished run 62/100 for degree_high
#
# [2026-03-24 19:45:14.246968] finished run 62/100 for degree_low
#
# [2026-03-24 19:45:14.884708] finished run 62/100 for degree_random
#
# [2026-03-24 19:45:15.370798] finished run 63/100 for betweenness_baseline
#
# [2026-03-24 19:45:16.193453] finished run 63/100 for betweenness_high
#
# [2026-03-24 19:45:16.864324] finished run 63/100 for betweenness_low
#
# [2026-03-24 19:45:17.635902] finished run 63/100 for betweenness_random
#
# [2026-03-24 19:45:18.10297] finished run 63/100 for degree_baseline
#
# [2026-03-24 19:45:18.777761] finished run 63/100 for degree_high
#
# [2026-03-24 19:45:19.5905] finished run 63/100 for degree_low
#
# [2026-03-24 19:45:20.232224] finished run 63/100 for degree_random
#
# [2026-03-24 19:45:20.70415] finished run 64/100 for betweenness_baseline
#
# [2026-03-24 19:45:21.37677] finished run 64/100 for betweenness_high
#
# [2026-03-24 19:45:22.057917] finished run 64/100 for betweenness_low
#
# [2026-03-24 19:45:22.714291] finished run 64/100 for betweenness_random
#
# [2026-03-24 19:45:23.210648] finished run 64/100 for degree_baseline
#
# [2026-03-24 19:45:24.019854] finished run 64/100 for degree_high
#
# [2026-03-24 19:45:24.697912] finished run 64/100 for degree_low
#
# [2026-03-24 19:45:25.337577] finished run 64/100 for degree_random
#
# [2026-03-24 19:45:25.805578] finished run 65/100 for betweenness_baseline
#
# [2026-03-24 19:45:26.617339] finished run 65/100 for betweenness_high
#
# [2026-03-24 19:45:27.42434] finished run 65/100 for betweenness_low
#
# [2026-03-24 19:45:28.199547] finished run 65/100 for betweenness_random
#
# [2026-03-24 19:45:28.801316] finished run 65/100 for degree_baseline
#
# [2026-03-24 19:45:29.617823] finished run 65/100 for degree_high
#
# [2026-03-24 19:45:30.437358] finished run 65/100 for degree_low
#
# [2026-03-24 19:45:31.209361] finished run 65/100 for degree_random
#
# [2026-03-24 19:45:31.817204] finished run 66/100 for betweenness_baseline
#
# [2026-03-24 19:45:32.488906] finished run 66/100 for betweenness_high
#
# [2026-03-24 19:45:33.166259] finished run 66/100 for betweenness_low
#
# [2026-03-24 19:45:34.002872] finished run 66/100 for betweenness_random
#
# [2026-03-24 19:45:34.462867] finished run 66/100 for degree_baseline
#
# [2026-03-24 19:45:35.14074] finished run 66/100 for degree_high
#
# [2026-03-24 19:45:35.814701] finished run 66/100 for degree_low
#
# [2026-03-24 19:45:36.455024] finished run 66/100 for degree_random
#
# [2026-03-24 19:45:36.921493] finished run 67/100 for betweenness_baseline
#
# [2026-03-24 19:45:37.607644] finished run 67/100 for betweenness_high
#
# [2026-03-24 19:45:38.420989] finished run 67/100 for betweenness_low
#
# [2026-03-24 19:45:39.05461] finished run 67/100 for betweenness_random
#
# [2026-03-24 19:45:39.527802] finished run 67/100 for degree_baseline
#
# [2026-03-24 19:45:40.213631] finished run 67/100 for degree_high
#
# [2026-03-24 19:45:40.893567] finished run 67/100 for degree_low
#
# [2026-03-24 19:45:41.673183] finished run 67/100 for degree_random
#
# [2026-03-24 19:45:42.275541] finished run 68/100 for betweenness_baseline
#
# [2026-03-24 19:45:42.952661] finished run 68/100 for betweenness_high
#
# [2026-03-24 19:45:43.634436] finished run 68/100 for betweenness_low
#
# [2026-03-24 19:45:44.272925] finished run 68/100 for betweenness_random
#
# [2026-03-24 19:45:44.76525] finished run 68/100 for degree_baseline
#
# [2026-03-24 19:45:45.487273] finished run 68/100 for degree_high
#
# [2026-03-24 19:45:46.30594] finished run 68/100 for degree_low
#
# [2026-03-24 19:45:46.943645] finished run 68/100 for degree_random
#
# [2026-03-24 19:45:47.412019] finished run 69/100 for betweenness_baseline
#
# [2026-03-24 19:45:48.094488] finished run 69/100 for betweenness_high
#
# [2026-03-24 19:45:48.772442] finished run 69/100 for betweenness_low
#
# [2026-03-24 19:45:49.413933] finished run 69/100 for betweenness_random
#
# [2026-03-24 19:45:50.022539] finished run 69/100 for degree_baseline
#
# [2026-03-24 19:45:50.694598] finished run 69/100 for degree_high
#
# [2026-03-24 19:45:51.374018] finished run 69/100 for degree_low
#
# [2026-03-24 19:45:52.012167] finished run 69/100 for degree_random
#
# [2026-03-24 19:45:52.490445] finished run 70/100 for betweenness_baseline
#
# [2026-03-24 19:45:53.307935] finished run 70/100 for betweenness_high
#
# [2026-03-24 19:45:54.122277] finished run 70/100 for betweenness_low
#
# [2026-03-24 19:45:54.891083] finished run 70/100 for betweenness_random
#
# [2026-03-24 19:45:55.498589] finished run 70/100 for degree_baseline
#
# [2026-03-24 19:45:56.305022] finished run 70/100 for degree_high
#
# [2026-03-24 19:45:57.116511] finished run 70/100 for degree_low
#
# [2026-03-24 19:45:57.886831] finished run 70/100 for degree_random
#
# [2026-03-24 19:45:58.490207] finished run 71/100 for betweenness_baseline
#
# [2026-03-24 19:45:59.163177] finished run 71/100 for betweenness_high
#
# [2026-03-24 19:45:59.840975] finished run 71/100 for betweenness_low
#
# [2026-03-24 19:46:00.541063] finished run 71/100 for betweenness_random
#
# [2026-03-24 19:46:01.009788] finished run 71/100 for degree_baseline
#
# [2026-03-24 19:46:01.708847] finished run 71/100 for degree_high
#
# [2026-03-24 19:46:02.387955] finished run 71/100 for degree_low
#
# [2026-03-24 19:46:03.160192] finished run 71/100 for degree_random
#
# [2026-03-24 19:46:03.626823] finished run 72/100 for betweenness_baseline
#
# [2026-03-24 19:46:04.304311] finished run 72/100 for betweenness_high
#
# [2026-03-24 19:46:05.111177] finished run 72/100 for betweenness_low
#
# [2026-03-24 19:46:05.75353] finished run 72/100 for betweenness_random
#
# [2026-03-24 19:46:06.219434] finished run 72/100 for degree_baseline
#
# [2026-03-24 19:46:06.900656] finished run 72/100 for degree_high
#
# [2026-03-24 19:46:07.575102] finished run 72/100 for degree_low
#
# [2026-03-24 19:46:08.219534] finished run 72/100 for degree_random
#
# [2026-03-24 19:46:08.83261] finished run 73/100 for betweenness_baseline
#
# [2026-03-24 19:46:09.503965] finished run 73/100 for betweenness_high
#
# [2026-03-24 19:46:10.192432] finished run 73/100 for betweenness_low
#
# [2026-03-24 19:46:10.832008] finished run 73/100 for betweenness_random
#
# [2026-03-24 19:46:11.311665] finished run 73/100 for degree_baseline
#
# [2026-03-24 19:46:12.137553] finished run 73/100 for degree_high
#
# [2026-03-24 19:46:12.813056] finished run 73/100 for degree_low
#
# [2026-03-24 19:46:13.45053] finished run 73/100 for degree_random
#
# [2026-03-24 19:46:13.924125] finished run 74/100 for betweenness_baseline
#
# [2026-03-24 19:46:14.608233] finished run 74/100 for betweenness_high
#
# [2026-03-24 19:46:15.297239] finished run 74/100 for betweenness_low
#
# [2026-03-24 19:46:15.946479] finished run 74/100 for betweenness_random
#
# [2026-03-24 19:46:16.556214] finished run 74/100 for degree_baseline
#
# [2026-03-24 19:46:17.233224] finished run 74/100 for degree_high
#
# [2026-03-24 19:46:17.911364] finished run 74/100 for degree_low
#
# [2026-03-24 19:46:18.684491] finished run 74/100 for degree_random
#
# [2026-03-24 19:46:19.15454] finished run 75/100 for betweenness_baseline
#
# [2026-03-24 19:46:19.973964] finished run 75/100 for betweenness_high
#
# [2026-03-24 19:46:20.783821] finished run 75/100 for betweenness_low
#
# [2026-03-24 19:46:21.56143] finished run 75/100 for betweenness_random
#
# [2026-03-24 19:46:22.168491] finished run 75/100 for degree_baseline
#
# [2026-03-24 19:46:22.983851] finished run 75/100 for degree_high
#
# [2026-03-24 19:46:23.795658] finished run 75/100 for degree_low
#
# [2026-03-24 19:46:24.570563] finished run 75/100 for degree_random
#
# [2026-03-24 19:46:25.176051] finished run 76/100 for betweenness_baseline
#
# [2026-03-24 19:46:25.845469] finished run 76/100 for betweenness_high
#
# [2026-03-24 19:46:26.521058] finished run 76/100 for betweenness_low
#
# [2026-03-24 19:46:27.221997] finished run 76/100 for betweenness_random
#
# [2026-03-24 19:46:27.691186] finished run 76/100 for degree_baseline
#
# [2026-03-24 19:46:28.368883] finished run 76/100 for degree_high
#
# [2026-03-24 19:46:29.052599] finished run 76/100 for degree_low
#
# [2026-03-24 19:46:29.836348] finished run 76/100 for degree_random
#
# [2026-03-24 19:46:30.307008] finished run 77/100 for betweenness_baseline
#
# [2026-03-24 19:46:30.986486] finished run 77/100 for betweenness_high
#
# [2026-03-24 19:46:31.66414] finished run 77/100 for betweenness_low
#
# [2026-03-24 19:46:32.444893] finished run 77/100 for betweenness_random
#
# [2026-03-24 19:46:32.915222] finished run 77/100 for degree_baseline
#
# [2026-03-24 19:46:33.593626] finished run 77/100 for degree_high
#
# [2026-03-24 19:46:34.271788] finished run 77/100 for degree_low
#
# [2026-03-24 19:46:34.916657] finished run 77/100 for degree_random
#
# [2026-03-24 19:46:35.53759] finished run 78/100 for betweenness_baseline
#
# [2026-03-24 19:46:36.210932] finished run 78/100 for betweenness_high
#
# [2026-03-24 19:46:36.891753] finished run 78/100 for betweenness_low
#
# [2026-03-24 19:46:37.531094] finished run 78/100 for betweenness_random
#
# [2026-03-24 19:46:38.01258] finished run 78/100 for degree_baseline
#
# [2026-03-24 19:46:38.826182] finished run 78/100 for degree_high
#
# [2026-03-24 19:46:39.502111] finished run 78/100 for degree_low
#
# [2026-03-24 19:46:40.141186] finished run 78/100 for degree_random
#
# [2026-03-24 19:46:40.621547] finished run 79/100 for betweenness_baseline
#
# [2026-03-24 19:46:41.305582] finished run 79/100 for betweenness_high
#
# [2026-03-24 19:46:41.987307] finished run 79/100 for betweenness_low
#
# [2026-03-24 19:46:42.673891] finished run 79/100 for betweenness_random
#
# [2026-03-24 19:46:43.287752] finished run 79/100 for degree_baseline
#
# [2026-03-24 19:46:43.961957] finished run 79/100 for degree_high
#
# [2026-03-24 19:46:44.659061] finished run 79/100 for degree_low
#
# [2026-03-24 19:46:45.319437] finished run 79/100 for degree_random
#
# [2026-03-24 19:46:45.79505] finished run 80/100 for betweenness_baseline
#
# [2026-03-24 19:46:46.604614] finished run 80/100 for betweenness_high
#
# [2026-03-24 19:46:47.41742] finished run 80/100 for betweenness_low
#
# [2026-03-24 19:46:48.191018] finished run 80/100 for betweenness_random
#
# [2026-03-24 19:46:48.794848] finished run 80/100 for degree_baseline
#
# [2026-03-24 19:46:49.602884] finished run 80/100 for degree_high
#
# [2026-03-24 19:46:50.41942] finished run 80/100 for degree_low
#
# [2026-03-24 19:46:51.208644] finished run 80/100 for degree_random
#
# [2026-03-24 19:46:51.816669] finished run 81/100 for betweenness_baseline
#
# [2026-03-24 19:46:52.48545] finished run 81/100 for betweenness_high
#
# [2026-03-24 19:46:53.16174] finished run 81/100 for betweenness_low
#
# [2026-03-24 19:46:53.990988] finished run 81/100 for betweenness_random
#
# [2026-03-24 19:46:54.454427] finished run 81/100 for degree_baseline
#
# [2026-03-24 19:46:55.132931] finished run 81/100 for degree_high
#
# [2026-03-24 19:46:55.810359] finished run 81/100 for degree_low
#
# [2026-03-24 19:46:56.447758] finished run 81/100 for degree_random
#
# [2026-03-24 19:46:56.914559] finished run 82/100 for betweenness_baseline
#
# [2026-03-24 19:46:57.60891] finished run 82/100 for betweenness_high
#
# [2026-03-24 19:46:58.425553] finished run 82/100 for betweenness_low
#
# [2026-03-24 19:46:59.06172] finished run 82/100 for betweenness_random
#
# [2026-03-24 19:46:59.535902] finished run 82/100 for degree_baseline
#
# [2026-03-24 19:47:00.218853] finished run 82/100 for degree_high
#
# [2026-03-24 19:47:00.905445] finished run 82/100 for degree_low
#
# [2026-03-24 19:47:01.718716] finished run 82/100 for degree_random
#
# [2026-03-24 19:47:02.191071] finished run 83/100 for betweenness_baseline
#
# [2026-03-24 19:47:03.003109] finished run 83/100 for betweenness_high
#
# [2026-03-24 19:47:03.67827] finished run 83/100 for betweenness_low
#
# [2026-03-24 19:47:04.332329] finished run 83/100 for betweenness_random
#
# [2026-03-24 19:47:04.821573] finished run 83/100 for degree_baseline
#
# [2026-03-24 19:47:05.50483] finished run 83/100 for degree_high
#
# [2026-03-24 19:47:06.194707] finished run 83/100 for degree_low
#
# [2026-03-24 19:47:06.878332] finished run 83/100 for degree_random
#
# [2026-03-24 19:47:07.487597] finished run 84/100 for betweenness_baseline
#
# [2026-03-24 19:47:08.162474] finished run 84/100 for betweenness_high
#
# [2026-03-24 19:47:08.838484] finished run 84/100 for betweenness_low
#
# [2026-03-24 19:47:09.488973] finished run 84/100 for betweenness_random
#
# [2026-03-24 19:47:09.962461] finished run 84/100 for degree_baseline
#
# [2026-03-24 19:47:10.781915] finished run 84/100 for degree_high
#
# [2026-03-24 19:47:11.450971] finished run 84/100 for degree_low
#
# [2026-03-24 19:47:12.097388] finished run 84/100 for degree_random
#
# [2026-03-24 19:47:12.567203] finished run 85/100 for betweenness_baseline
#
# [2026-03-24 19:47:13.378841] finished run 85/100 for betweenness_high
#
# [2026-03-24 19:47:14.19389] finished run 85/100 for betweenness_low
#
# [2026-03-24 19:47:14.966175] finished run 85/100 for betweenness_random
#
# [2026-03-24 19:47:15.56998] finished run 85/100 for degree_baseline
#
# [2026-03-24 19:47:16.38051] finished run 85/100 for degree_high
#
# [2026-03-24 19:47:17.194002] finished run 85/100 for degree_low
#
# [2026-03-24 19:47:17.964632] finished run 85/100 for degree_random
#
# [2026-03-24 19:47:18.568122] finished run 86/100 for betweenness_baseline
#
# [2026-03-24 19:47:19.241338] finished run 86/100 for betweenness_high
#
# [2026-03-24 19:47:19.919589] finished run 86/100 for betweenness_low
#
# [2026-03-24 19:47:20.619607] finished run 86/100 for betweenness_random
#
# [2026-03-24 19:47:21.088341] finished run 86/100 for degree_baseline
#
# [2026-03-24 19:47:21.78991] finished run 86/100 for degree_high
#
# [2026-03-24 19:47:22.471218] finished run 86/100 for degree_low
#
# [2026-03-24 19:47:23.245802] finished run 86/100 for degree_random
#
# [2026-03-24 19:47:23.716015] finished run 87/100 for betweenness_baseline
#
# [2026-03-24 19:47:24.396143] finished run 87/100 for betweenness_high
#
# [2026-03-24 19:47:25.210809] finished run 87/100 for betweenness_low
#
# [2026-03-24 19:47:25.844702] finished run 87/100 for betweenness_random
#
# [2026-03-24 19:47:26.321305] finished run 87/100 for degree_baseline
#
# [2026-03-24 19:47:26.999913] finished run 87/100 for degree_high
#
# [2026-03-24 19:47:27.68208] finished run 87/100 for degree_low
#
# [2026-03-24 19:47:28.467412] finished run 87/100 for degree_random
#
# [2026-03-24 19:47:28.935432] finished run 88/100 for betweenness_baseline
#
# [2026-03-24 19:47:29.611975] finished run 88/100 for betweenness_high
#
# [2026-03-24 19:47:30.300017] finished run 88/100 for betweenness_low
#
# [2026-03-24 19:47:30.947076] finished run 88/100 for betweenness_random
#
# [2026-03-24 19:47:31.566333] finished run 88/100 for degree_baseline
#
# [2026-03-24 19:47:32.237917] finished run 88/100 for degree_high
#
# [2026-03-24 19:47:32.918284] finished run 88/100 for degree_low
#
# [2026-03-24 19:47:33.564992] finished run 88/100 for degree_random
#
# [2026-03-24 19:47:34.054062] finished run 89/100 for betweenness_baseline
#
# [2026-03-24 19:47:34.8678] finished run 89/100 for betweenness_high
#
# [2026-03-24 19:47:35.546058] finished run 89/100 for betweenness_low
#
# [2026-03-24 19:47:36.178697] finished run 89/100 for betweenness_random
#
# [2026-03-24 19:47:36.65264] finished run 89/100 for degree_baseline
#
# [2026-03-24 19:47:37.329281] finished run 89/100 for degree_high
#
# [2026-03-24 19:47:38.015794] finished run 89/100 for degree_low
#
# [2026-03-24 19:47:38.654987] finished run 89/100 for degree_random
#
# [2026-03-24 19:47:39.268821] finished run 90/100 for betweenness_baseline
#
# [2026-03-24 19:47:40.085708] finished run 90/100 for betweenness_high
#
# [2026-03-24 19:47:40.899065] finished run 90/100 for betweenness_low
#
# [2026-03-24 19:47:41.669991] finished run 90/100 for betweenness_random
#
# [2026-03-24 19:47:42.281776] finished run 90/100 for degree_baseline
#
# [2026-03-24 19:47:43.090651] finished run 90/100 for degree_high
#
# [2026-03-24 19:47:43.903825] finished run 90/100 for degree_low
#
# [2026-03-24 19:47:44.675213] finished run 90/100 for degree_random
#
# [2026-03-24 19:47:45.278124] finished run 91/100 for betweenness_baseline
#
# [2026-03-24 19:47:45.951318] finished run 91/100 for betweenness_high
#
# [2026-03-24 19:47:46.629504] finished run 91/100 for betweenness_low
#
# [2026-03-24 19:47:47.323971] finished run 91/100 for betweenness_random
#
# [2026-03-24 19:47:47.791071] finished run 91/100 for degree_baseline
#
# [2026-03-24 19:47:48.473587] finished run 91/100 for degree_high
#
# [2026-03-24 19:47:49.15349] finished run 91/100 for degree_low
#
# [2026-03-24 19:47:49.950132] finished run 91/100 for degree_random
#
# [2026-03-24 19:47:50.419091] finished run 92/100 for betweenness_baseline
#
# [2026-03-24 19:47:51.097131] finished run 92/100 for betweenness_high
#
# [2026-03-24 19:47:51.780598] finished run 92/100 for betweenness_low
#
# [2026-03-24 19:47:52.559522] finished run 92/100 for betweenness_random
#
# [2026-03-24 19:47:53.027467] finished run 92/100 for degree_baseline
#
# [2026-03-24 19:47:53.703023] finished run 92/100 for degree_high
#
# [2026-03-24 19:47:54.389075] finished run 92/100 for degree_low
#
# [2026-03-24 19:47:55.031073] finished run 92/100 for degree_random
#
# [2026-03-24 19:47:55.6536] finished run 93/100 for betweenness_baseline
#
# [2026-03-24 19:47:56.328558] finished run 93/100 for betweenness_high
#
# [2026-03-24 19:47:57.011319] finished run 93/100 for betweenness_low
#
# [2026-03-24 19:47:57.655962] finished run 93/100 for betweenness_random
#
# [2026-03-24 19:47:58.138605] finished run 93/100 for degree_baseline
#
# [2026-03-24 19:47:58.954497] finished run 93/100 for degree_high
#
# [2026-03-24 19:47:59.634488] finished run 93/100 for degree_low
#
# [2026-03-24 19:48:00.271932] finished run 93/100 for degree_random
#
# [2026-03-24 19:48:00.755381] finished run 94/100 for betweenness_baseline
#
# [2026-03-24 19:48:01.439023] finished run 94/100 for betweenness_high
#
# [2026-03-24 19:48:02.132833] finished run 94/100 for betweenness_low
#
# [2026-03-24 19:48:02.812659] finished run 94/100 for betweenness_random
#
# [2026-03-24 19:48:03.422008] finished run 94/100 for degree_baseline
#
# [2026-03-24 19:48:04.09582] finished run 94/100 for degree_high
#
# [2026-03-24 19:48:04.774499] finished run 94/100 for degree_low
#
# [2026-03-24 19:48:05.419347] finished run 94/100 for degree_random
#
# [2026-03-24 19:48:05.893637] finished run 95/100 for betweenness_baseline
#
# [2026-03-24 19:48:06.707867] finished run 95/100 for betweenness_high
#
# [2026-03-24 19:48:07.516711] finished run 95/100 for betweenness_low
#
# [2026-03-24 19:48:08.293335] finished run 95/100 for betweenness_random
#
# [2026-03-24 19:48:08.896144] finished run 95/100 for degree_baseline
#
# [2026-03-24 19:48:09.709667] finished run 95/100 for degree_high
#
# [2026-03-24 19:48:10.524847] finished run 95/100 for degree_low
#
# [2026-03-24 19:48:11.300262] finished run 95/100 for degree_random
#
# [2026-03-24 19:48:11.904175] finished run 96/100 for betweenness_baseline
#
# [2026-03-24 19:48:12.577146] finished run 96/100 for betweenness_high
#
# [2026-03-24 19:48:13.254125] finished run 96/100 for betweenness_low
#
# [2026-03-24 19:48:14.074752] finished run 96/100 for betweenness_random
#
# [2026-03-24 19:48:14.535962] finished run 96/100 for degree_baseline
#
# [2026-03-24 19:48:15.210981] finished run 96/100 for degree_high
#
# [2026-03-24 19:48:15.884922] finished run 96/100 for degree_low
#
# [2026-03-24 19:48:16.527129] finished run 96/100 for degree_random
#
# [2026-03-24 19:48:16.995531] finished run 97/100 for betweenness_baseline
#
# [2026-03-24 19:48:17.692121] finished run 97/100 for betweenness_high
#
# [2026-03-24 19:48:18.517178] finished run 97/100 for betweenness_low
#
# [2026-03-24 19:48:19.152332] finished run 97/100 for betweenness_random
#
# [2026-03-24 19:48:19.62593] finished run 97/100 for degree_baseline
#
# [2026-03-24 19:48:20.310505] finished run 97/100 for degree_high
#
# [2026-03-24 19:48:20.991861] finished run 97/100 for degree_low
#
# [2026-03-24 19:48:21.772697] finished run 97/100 for degree_random
#
# [2026-03-24 19:48:22.242887] finished run 98/100 for betweenness_baseline
#
# [2026-03-24 19:48:22.924202] finished run 98/100 for betweenness_high
#
# [2026-03-24 19:48:23.746192] finished run 98/100 for betweenness_low
#
# [2026-03-24 19:48:24.390005] finished run 98/100 for betweenness_random
#
# [2026-03-24 19:48:24.867384] finished run 98/100 for degree_baseline
#
# [2026-03-24 19:48:25.541185] finished run 98/100 for degree_high
#
# [2026-03-24 19:48:26.220202] finished run 98/100 for degree_low
#
# [2026-03-24 19:48:26.875596] finished run 98/100 for degree_random
#
# [2026-03-24 19:48:27.381561] finished run 99/100 for betweenness_baseline
#
# [2026-03-24 19:48:28.197939] finished run 99/100 for betweenness_high
#
# [2026-03-24 19:48:28.877723] finished run 99/100 for betweenness_low
#
# [2026-03-24 19:48:29.516222] finished run 99/100 for betweenness_random
#
# [2026-03-24 19:48:29.986522] finished run 99/100 for degree_baseline
#
# [2026-03-24 19:48:30.668052] finished run 99/100 for degree_high
#
# [2026-03-24 19:48:31.487853] finished run 99/100 for degree_low
#
# [2026-03-24 19:48:32.121709] finished run 99/100 for degree_random
#
# [2026-03-24 19:48:32.595978] finished run 100/100 for betweenness_baseline
#
# [2026-03-24 19:48:33.419052] finished run 100/100 for betweenness_high
#
# [2026-03-24 19:48:34.228615] finished run 100/100 for betweenness_low
#
# [2026-03-24 19:48:35.005467] finished run 100/100 for betweenness_random
#
# [2026-03-24 19:48:35.608521] finished run 100/100 for degree_baseline
#
# [2026-03-24 19:48:36.421842] finished run 100/100 for degree_high
#
# [2026-03-24 19:48:37.232583] finished run 100/100 for degree_low
#
# [2026-03-24 19:48:38.007959] finished run 100/100 for degree_random
